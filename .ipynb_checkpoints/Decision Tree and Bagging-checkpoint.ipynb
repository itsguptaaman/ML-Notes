# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from pandas_profiling import profile_report
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, roc_curve
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\Aman\Downloads\wineQT.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4        5     0
# 1         9.8        5     1
# 2         9.8        5     2
# 3         9.8        6     3
# 4         9.4        5     4
# ...       ...      ...   ...
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597
#
# [1143 rows x 13 columns]

# %%
df.quality.value_counts()
set(df.quality)
# Out:
# {3, 4, 5, 6, 7, 8}

# %%
pf=df.profile_report()
pf.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/26 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
X=df.drop(columns=['quality'])
y=df['quality']
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol    Id
# 0         9.4     0
# 1         9.8     1
# 2         9.8     2
# 3         9.8     3
# 4         9.4     4
# ...       ...   ...
# 1138     11.0  1592
# 1139      9.5  1593
# 1140     10.5  1594
# 1141     11.2  1595
# 1142     10.2  1597
#
# [1143 rows x 12 columns]

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1138    6
# 1139    6
# 1140    5
# 1141    6
# 1142    5
# Name: quality, Length: 1143, dtype: int64

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=.20,random_state=100)

# %%
decision_tree=DecisionTreeClassifier()

# %%
decision_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
sklearn.__version__
# Out:
# '1.1.1'

# %%
plt.figure(figsize=(10,20))
tree.plot_tree(decision_tree,filled=True)
# Out:
# [Text(0.5057646413828689, 0.9666666666666667, 'X[10] <= 10.525\ngini = 0.648\nsamples = 914\nvalue = [6, 25, 381, 365, 121, 16]'),
#  Text(0.27879901960784315, 0.9, 'X[9] <= 0.595\ngini = 0.545\nsamples = 547\nvalue = [5, 17, 319, 183, 21, 2]'),
#  Text(0.11016511867905057, 0.8333333333333334, 'X[6] <= 98.5\ngini = 0.447\nsamples = 257\nvalue = [3, 11, 182, 57, 4, 0]'),
#  Text(0.10603715170278638, 0.7666666666666667, 'X[9] <= 0.525\ngini = 0.49\nsamples = 224\nvalue = [3, 11, 149, 57, 4, 0]'),
#  Text(0.0392156862745098, 0.7, 'X[0] <= 7.85\ngini = 0.369\nsamples = 91\nvalue = [1, 6, 71, 12, 1, 0]'),
#  Text(0.016511867905056758, 0.6333333333333333, 'X[11] <= 1432.5\ngini = 0.194\nsamples = 48\nvalue = [1, 1, 43, 2, 1, 0]'),
#  Text(0.008255933952528379, 0.5666666666666667, 'X[0] <= 5.3\ngini = 0.125\nsamples = 46\nvalue = [0, 1, 43, 1, 1, 0]'),
#  Text(0.0041279669762641896, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.01238390092879257, 0.5, 'X[11] <= 9.5\ngini = 0.086\nsamples = 45\nvalue = [0, 0, 43, 1, 1, 0]'),
#  Text(0.008255933952528379, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.016511867905056758, 0.43333333333333335, 'X[11] <= 1372.0\ngini = 0.044\nsamples = 44\nvalue = [0, 0, 43, 1, 0, 0]'),
#  Text(0.01238390092879257, 0.36666666666666664, 'gini = 0.0\nsamples = 39\nvalue = [0, 0, 39, 0, 0, 0]'),
#  Text(0.02063983488132095, 0.36666666666666664, 'X[7] <= 0.996\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.016511867905056758, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.02476780185758514, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.02476780185758514, 0.5666666666666667, 'X[0] <= 7.25\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1, 0, 0]'),
#  Text(0.02063983488132095, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.02889576883384933, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.06191950464396285, 0.6333333333333333, 'X[10] <= 9.65\ngini = 0.508\nsamples = 43\nvalue = [0, 5, 28, 10, 0, 0]'),
#  Text(0.04540763673890609, 0.5666666666666667, 'X[1] <= 0.825\ngini = 0.368\nsamples = 27\nvalue = [0, 4, 21, 2, 0, 0]'),
#  Text(0.03715170278637771, 0.5, 'X[10] <= 9.05\ngini = 0.226\nsamples = 24\nvalue = [0, 2, 21, 1, 0, 0]'),
#  Text(0.033023735810113516, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.0412796697626419, 0.43333333333333335, 'X[8] <= 3.37\ngini = 0.159\nsamples = 23\nvalue = [0, 2, 21, 0, 0, 0]'),
#  Text(0.03715170278637771, 0.36666666666666664, 'X[11] <= 72.0\ngini = 0.087\nsamples = 22\nvalue = [0, 1, 21, 0, 0, 0]'),
#  Text(0.033023735810113516, 0.3, 'X[6] <= 52.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.02889576883384933, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.03715170278637771, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.0412796697626419, 0.3, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 20, 0, 0, 0]'),
#  Text(0.04540763673890609, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.053663570691434466, 0.5, 'X[9] <= 0.46\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 1, 0, 0]'),
#  Text(0.04953560371517028, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.05779153766769866, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.0784313725490196, 0.5666666666666667, 'X[8] <= 3.225\ngini = 0.555\nsamples = 16\nvalue = [0, 1, 7, 8, 0, 0]'),
#  Text(0.07017543859649122, 0.5, 'X[1] <= 0.657\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 2, 7, 0, 0]'),
#  Text(0.06604747162022703, 0.43333333333333335, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.07430340557275542, 0.43333333333333335, 'X[10] <= 9.85\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.07017543859649122, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.0784313725490196, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.08668730650154799, 0.5, 'X[6] <= 15.5\ngini = 0.449\nsamples = 7\nvalue = [0, 1, 5, 1, 0, 0]'),
#  Text(0.0825593395252838, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.09081527347781218, 0.43333333333333335, 'X[2] <= 0.3\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.08668730650154799, 0.36666666666666664, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.09494324045407637, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.17285861713106296, 0.7, 'X[7] <= 0.997\ngini = 0.539\nsamples = 133\nvalue = [2, 5, 78, 45, 3, 0]'),
#  Text(0.13622291021671826, 0.6333333333333333, 'X[11] <= 1477.0\ngini = 0.562\nsamples = 75\nvalue = [1, 1, 35, 35, 3, 0]'),
#  Text(0.13209494324045407, 0.5666666666666667, 'X[5] <= 12.5\ngini = 0.563\nsamples = 68\nvalue = [1, 1, 28, 35, 3, 0]'),
#  Text(0.11558307533539731, 0.5, 'X[10] <= 10.1\ngini = 0.554\nsamples = 36\nvalue = [0, 0, 20, 13, 3, 0]'),
#  Text(0.10732714138286893, 0.43333333333333335, 'X[6] <= 9.5\ngini = 0.457\nsamples = 28\nvalue = [0, 0, 19, 8, 1, 0]'),
#  Text(0.10319917440660474, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.11145510835913312, 0.36666666666666664, 'X[7] <= 0.997\ngini = 0.411\nsamples = 26\nvalue = [0, 0, 19, 6, 1, 0]'),
#  Text(0.10732714138286893, 0.3, 'X[11] <= 69.5\ngini = 0.344\nsamples = 24\nvalue = [0, 0, 19, 4, 1, 0]'),
#  Text(0.09907120743034056, 0.23333333333333334, 'X[8] <= 3.37\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 2, 1, 0]'),
#  Text(0.09494324045407637, 0.16666666666666666, 'X[10] <= 9.4\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.09081527347781218, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.09907120743034056, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.10319917440660474, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.11558307533539731, 0.23333333333333334, 'X[4] <= 0.065\ngini = 0.18\nsamples = 20\nvalue = [0, 0, 18, 2, 0, 0]'),
#  Text(0.11145510835913312, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1197110423116615, 0.16666666666666666, 'X[1] <= 0.515\ngini = 0.1\nsamples = 19\nvalue = [0, 0, 18, 1, 0, 0]'),
#  Text(0.11558307533539731, 0.1, 'X[4] <= 0.071\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.11145510835913312, 0.03333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.1197110423116615, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1238390092879257, 0.1, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 16, 0, 0, 0]'),
#  Text(0.11558307533539731, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.1238390092879257, 0.43333333333333335, 'X[10] <= 10.45\ngini = 0.531\nsamples = 8\nvalue = [0, 0, 1, 5, 2, 0]'),
#  Text(0.1197110423116615, 0.36666666666666664, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.12796697626418987, 0.36666666666666664, 'X[11] <= 1023.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(0.1238390092879257, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.13209494324045407, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.14860681114551083, 0.5, 'X[5] <= 23.5\ngini = 0.463\nsamples = 32\nvalue = [1, 1, 8, 22, 0, 0]'),
#  Text(0.14035087719298245, 0.43333333333333335, 'X[11] <= 109.5\ngini = 0.299\nsamples = 23\nvalue = [1, 0, 3, 19, 0, 0]'),
#  Text(0.13622291021671826, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.14447884416924664, 0.36666666666666664, 'X[7] <= 0.997\ngini = 0.177\nsamples = 21\nvalue = [1, 0, 1, 19, 0, 0]'),
#  Text(0.14035087719298245, 0.3, 'X[9] <= 0.585\ngini = 0.095\nsamples = 20\nvalue = [0, 0, 1, 19, 0, 0]'),
#  Text(0.13622291021671826, 0.23333333333333334, 'gini = 0.0\nsamples = 18\nvalue = [0, 0, 0, 18, 0, 0]'),
#  Text(0.14447884416924664, 0.23333333333333334, 'X[3] <= 2.1\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.14035087719298245, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.14860681114551083, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.14860681114551083, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.1568627450980392, 0.43333333333333335, 'X[5] <= 27.5\ngini = 0.568\nsamples = 9\nvalue = [0, 1, 5, 3, 0, 0]'),
#  Text(0.15273477812177502, 0.36666666666666664, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.1609907120743034, 0.36666666666666664, 'X[2] <= 0.245\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 1, 3, 0, 0]'),
#  Text(0.1568627450980392, 0.3, 'X[7] <= 0.995\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.15273477812177502, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.1609907120743034, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.1651186790505676, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.14035087719298245, 0.5666666666666667, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.20949432404540763, 0.6333333333333333, 'X[8] <= 3.545\ngini = 0.416\nsamples = 58\nvalue = [1, 4, 43, 10, 0, 0]'),
#  Text(0.20536635706914344, 0.5666666666666667, 'X[9] <= 0.585\ngini = 0.385\nsamples = 56\nvalue = [1, 4, 43, 8, 0, 0]'),
#  Text(0.19195046439628483, 0.5, 'X[7] <= 0.998\ngini = 0.331\nsamples = 52\nvalue = [1, 3, 42, 6, 0, 0]'),
#  Text(0.18163054695562436, 0.43333333333333335, 'X[9] <= 0.535\ngini = 0.077\nsamples = 25\nvalue = [0, 1, 24, 0, 0, 0]'),
#  Text(0.17750257997936017, 0.36666666666666664, 'X[10] <= 9.1\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.17337461300309598, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.18163054695562436, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.18575851393188855, 0.36666666666666664, 'gini = 0.0\nsamples = 23\nvalue = [0, 0, 23, 0, 0, 0]'),
#  Text(0.20227038183694532, 0.43333333333333335, 'X[4] <= 0.079\ngini = 0.499\nsamples = 27\nvalue = [1, 2, 18, 6, 0, 0]'),
#  Text(0.19401444788441694, 0.36666666666666664, 'X[6] <= 59.0\ngini = 0.735\nsamples = 7\nvalue = [1, 2, 2, 2, 0, 0]'),
#  Text(0.18988648090815274, 0.3, 'X[10] <= 9.75\ngini = 0.64\nsamples = 5\nvalue = [1, 2, 2, 0, 0, 0]'),
#  Text(0.18575851393188855, 0.23333333333333334, 'X[2] <= 0.575\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0, 0, 0]'),
#  Text(0.18163054695562436, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.18988648090815274, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.19401444788441694, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.19814241486068113, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.21052631578947367, 0.36666666666666664, 'X[4] <= 0.091\ngini = 0.32\nsamples = 20\nvalue = [0, 0, 16, 4, 0, 0]'),
#  Text(0.20639834881320948, 0.3, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.21465428276573786, 0.3, 'X[4] <= 0.094\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 5, 4, 0, 0]'),
#  Text(0.21052631578947367, 0.23333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.21878224974200206, 0.23333333333333334, 'X[7] <= 1.0\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.21465428276573786, 0.16666666666666666, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.22291021671826625, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.21878224974200206, 0.5, 'X[3] <= 2.05\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 1, 2, 0, 0]'),
#  Text(0.21465428276573786, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.22291021671826625, 0.43333333333333335, 'X[7] <= 0.997\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.21878224974200206, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.22703818369453044, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.21362229102167182, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.11429308565531476, 0.7666666666666667, 'gini = 0.0\nsamples = 33\nvalue = [0, 0, 33, 0, 0, 0]'),
#  Text(0.4474329205366357, 0.8333333333333334, 'X[0] <= 10.85\ngini = 0.584\nsamples = 290\nvalue = [2, 6, 137, 126, 17, 2]'),
#  Text(0.3897058823529412, 0.7666666666666667, 'X[10] <= 9.85\ngini = 0.556\nsamples = 248\nvalue = [2, 5, 132, 99, 9, 1]'),
#  Text(0.33410732714138286, 0.7, 'X[2] <= 0.445\ngini = 0.49\nsamples = 161\nvalue = [1, 4, 102, 53, 1, 0]'),
#  Text(0.30082559339525283, 0.6333333333333333, 'X[1] <= 0.555\ngini = 0.51\nsamples = 132\nvalue = [0, 3, 77, 51, 1, 0]'),
#  Text(0.26522187822497423, 0.5666666666666667, 'X[6] <= 29.0\ngini = 0.51\nsamples = 69\nvalue = [0, 0, 31, 37, 1, 0]'),
#  Text(0.2476780185758514, 0.5, 'X[10] <= 9.25\ngini = 0.308\nsamples = 21\nvalue = [0, 0, 4, 17, 0, 0]'),
#  Text(0.239422084623323, 0.43333333333333335, 'X[8] <= 3.275\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.23529411764705882, 0.36666666666666664, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.2435500515995872, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.25593395252837975, 0.43333333333333335, 'X[1] <= 0.335\ngini = 0.117\nsamples = 16\nvalue = [0, 0, 1, 15, 0, 0]'),
#  Text(0.2518059855521156, 0.36666666666666664, 'X[0] <= 8.8\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.2476780185758514, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.25593395252837975, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.26006191950464397, 0.36666666666666664, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.28276573787409703, 0.5, 'X[7] <= 0.997\ngini = 0.51\nsamples = 48\nvalue = [0, 0, 27, 20, 1, 0]'),
#  Text(0.2724458204334365, 0.43333333333333335, 'X[8] <= 3.455\ngini = 0.278\nsamples = 12\nvalue = [0, 0, 10, 2, 0, 0]'),
#  Text(0.26831785345717235, 0.36666666666666664, 'X[7] <= 0.996\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 10, 1, 0, 0]'),
#  Text(0.26418988648090813, 0.3, 'X[0] <= 6.75\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.26006191950464397, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.26831785345717235, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2724458204334365, 0.3, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.27657378740970073, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2930856553147575, 0.43333333333333335, 'X[9] <= 0.66\ngini = 0.526\nsamples = 36\nvalue = [0, 0, 17, 18, 1, 0]'),
#  Text(0.2848297213622291, 0.36666666666666664, 'X[7] <= 0.997\ngini = 0.473\nsamples = 26\nvalue = [0, 0, 16, 10, 0, 0]'),
#  Text(0.2807017543859649, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.2889576883384933, 0.3, 'X[5] <= 8.0\ngini = 0.397\nsamples = 22\nvalue = [0, 0, 16, 6, 0, 0]'),
#  Text(0.2848297213622291, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2930856553147575, 0.23333333333333334, 'X[0] <= 7.7\ngini = 0.32\nsamples = 20\nvalue = [0, 0, 16, 4, 0, 0]'),
#  Text(0.2889576883384933, 0.16666666666666666, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.29721362229102166, 0.16666666666666666, 'X[10] <= 9.45\ngini = 0.463\nsamples = 11\nvalue = [0, 0, 7, 4, 0, 0]'),
#  Text(0.2930856553147575, 0.1, 'X[0] <= 7.9\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 7, 1, 0, 0]'),
#  Text(0.2889576883384933, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.29721362229102166, 0.03333333333333333, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.3013415892672859, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.3013415892672859, 0.36666666666666664, 'X[8] <= 3.13\ngini = 0.34\nsamples = 10\nvalue = [0, 0, 1, 8, 1, 0]'),
#  Text(0.29721362229102166, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.30546955624355004, 0.3, 'X[6] <= 30.5\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 0, 8, 1, 0]'),
#  Text(0.3013415892672859, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.30959752321981426, 0.23333333333333334, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.3364293085655315, 0.5666666666666667, 'X[11] <= 553.5\ngini = 0.415\nsamples = 63\nvalue = [0, 3, 46, 14, 0, 0]'),
#  Text(0.32610939112487103, 0.5, 'X[3] <= 1.4\ngini = 0.275\nsamples = 32\nvalue = [0, 3, 27, 2, 0, 0]'),
#  Text(0.3219814241486068, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.3302373581011352, 0.43333333333333335, 'X[6] <= 116.5\ngini = 0.233\nsamples = 31\nvalue = [0, 2, 27, 2, 0, 0]'),
#  Text(0.32610939112487103, 0.36666666666666664, 'X[1] <= 0.955\ngini = 0.184\nsamples = 30\nvalue = [0, 1, 27, 2, 0, 0]'),
#  Text(0.3219814241486068, 0.3, 'X[1] <= 0.718\ngini = 0.128\nsamples = 29\nvalue = [0, 0, 27, 2, 0, 0]'),
#  Text(0.31785345717234265, 0.23333333333333334, 'gini = 0.0\nsamples = 21\nvalue = [0, 0, 21, 0, 0, 0]'),
#  Text(0.32610939112487103, 0.23333333333333334, 'X[7] <= 0.997\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 6, 2, 0, 0]'),
#  Text(0.3219814241486068, 0.16666666666666666, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.3302373581011352, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3302373581011352, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.33436532507739936, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.34674922600619196, 0.5, 'X[10] <= 9.15\ngini = 0.475\nsamples = 31\nvalue = [0, 0, 19, 12, 0, 0]'),
#  Text(0.34262125902992774, 0.43333333333333335, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.3508771929824561, 0.43333333333333335, 'X[0] <= 6.7\ngini = 0.436\nsamples = 28\nvalue = [0, 0, 19, 9, 0, 0]'),
#  Text(0.34674922600619196, 0.36666666666666664, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.35500515995872034, 0.36666666666666664, 'X[0] <= 8.05\ngini = 0.483\nsamples = 22\nvalue = [0, 0, 13, 9, 0, 0]'),
#  Text(0.3508771929824561, 0.3, 'X[5] <= 17.5\ngini = 0.492\nsamples = 16\nvalue = [0, 0, 7, 9, 0, 0]'),
#  Text(0.34262125902992774, 0.23333333333333334, 'X[10] <= 9.75\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 8, 0, 0]'),
#  Text(0.3384932920536636, 0.16666666666666666, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.34674922600619196, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3591331269349845, 0.23333333333333334, 'X[9] <= 0.78\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(0.35500515995872034, 0.16666666666666666, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.3632610939112487, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3591331269349845, 0.3, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.3673890608875129, 0.6333333333333333, 'X[9] <= 1.475\ngini = 0.25\nsamples = 29\nvalue = [1, 1, 25, 2, 0, 0]'),
#  Text(0.3591331269349845, 0.5666666666666667, 'X[11] <= 37.5\ngini = 0.14\nsamples = 27\nvalue = [1, 0, 25, 1, 0, 0]'),
#  Text(0.35500515995872034, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3632610939112487, 0.5, 'X[10] <= 8.6\ngini = 0.074\nsamples = 26\nvalue = [1, 0, 25, 0, 0, 0]'),
#  Text(0.3591331269349845, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.3673890608875129, 0.43333333333333335, 'gini = 0.0\nsamples = 25\nvalue = [0, 0, 25, 0, 0, 0]'),
#  Text(0.37564499484004127, 0.5666666666666667, 'X[9] <= 1.805\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.3715170278637771, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3797729618163055, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.4453044375644995, 0.7, 'X[1] <= 0.688\ngini = 0.593\nsamples = 87\nvalue = [1, 1, 30, 46, 8, 1]'),
#  Text(0.4200206398348813, 0.6333333333333333, 'X[11] <= 1284.5\ngini = 0.55\nsamples = 75\nvalue = [0, 0, 21, 45, 8, 1]'),
#  Text(0.39834881320949433, 0.5666666666666667, 'X[10] <= 10.35\ngini = 0.426\nsamples = 55\nvalue = [0, 0, 11, 40, 4, 0]'),
#  Text(0.38802889576883387, 0.5, 'X[4] <= 0.113\ngini = 0.251\nsamples = 35\nvalue = [0, 0, 4, 30, 1, 0]'),
#  Text(0.38390092879256965, 0.43333333333333335, 'X[11] <= 1119.0\ngini = 0.213\nsamples = 34\nvalue = [0, 0, 3, 30, 1, 0]'),
#  Text(0.37564499484004127, 0.36666666666666664, 'X[0] <= 9.55\ngini = 0.127\nsamples = 30\nvalue = [0, 0, 1, 28, 1, 0]'),
#  Text(0.3715170278637771, 0.3, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 0, 22, 0, 0]'),
#  Text(0.3797729618163055, 0.3, 'X[5] <= 14.0\ngini = 0.406\nsamples = 8\nvalue = [0, 0, 1, 6, 1, 0]'),
#  Text(0.37564499484004127, 0.23333333333333334, 'X[0] <= 9.85\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.3715170278637771, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3797729618163055, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.38390092879256965, 0.23333333333333334, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.39215686274509803, 0.36666666666666664, 'X[6] <= 53.0\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.38802889576883387, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.39628482972136225, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.39215686274509803, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4086687306501548, 0.5, 'X[11] <= 1088.5\ngini = 0.605\nsamples = 20\nvalue = [0, 0, 7, 10, 3, 0]'),
#  Text(0.40454076367389064, 0.43333333333333335, 'X[0] <= 7.3\ngini = 0.622\nsamples = 14\nvalue = [0, 0, 7, 4, 3, 0]'),
#  Text(0.4004127966976264, 0.36666666666666664, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.4086687306501548, 0.36666666666666664, 'X[9] <= 0.73\ngini = 0.642\nsamples = 9\nvalue = [0, 0, 2, 4, 3, 0]'),
#  Text(0.40454076367389064, 0.3, 'X[1] <= 0.37\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 2, 4, 0, 0]'),
#  Text(0.4004127966976264, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.4086687306501548, 0.23333333333333334, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.41279669762641896, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.41279669762641896, 0.43333333333333335, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.44169246646026833, 0.5666666666666667, 'X[10] <= 10.15\ngini = 0.645\nsamples = 20\nvalue = [0, 0, 10, 5, 4, 1]'),
#  Text(0.43343653250773995, 0.5, 'X[11] <= 1511.0\ngini = 0.667\nsamples = 9\nvalue = [0, 0, 1, 3, 4, 1]'),
#  Text(0.4293085655314757, 0.43333333333333335, 'X[11] <= 1423.0\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 1, 0, 4, 1]'),
#  Text(0.42518059855521156, 0.36666666666666664, 'X[0] <= 8.55\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1]'),
#  Text(0.42105263157894735, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.4293085655314757, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.43343653250773995, 0.36666666666666664, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.4375644994840041, 0.43333333333333335, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.4499484004127967, 0.5, 'X[9] <= 1.175\ngini = 0.298\nsamples = 11\nvalue = [0, 0, 9, 2, 0, 0]'),
#  Text(0.4458204334365325, 0.43333333333333335, 'X[4] <= 0.06\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 9, 1, 0, 0]'),
#  Text(0.44169246646026833, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4499484004127967, 0.36666666666666664, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.4540763673890609, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.47058823529411764, 0.6333333333333333, 'X[6] <= 17.0\ngini = 0.417\nsamples = 12\nvalue = [1, 1, 9, 1, 0, 0]'),
#  Text(0.46233230134158926, 0.5666666666666667, 'X[9] <= 0.62\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0, 0]'),
#  Text(0.4582043343653251, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.4664602683178535, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.478844169246646, 0.5666666666666667, 'X[6] <= 67.0\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 9, 1, 0, 0]'),
#  Text(0.47471620227038186, 0.5, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.48297213622291024, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5051599587203303, 0.7666666666666667, 'X[0] <= 11.55\ngini = 0.535\nsamples = 42\nvalue = [0, 1, 5, 27, 8, 1]'),
#  Text(0.4932920536635707, 0.7, 'X[2] <= 0.425\ngini = 0.133\nsamples = 14\nvalue = [0, 0, 1, 13, 0, 0]'),
#  Text(0.4891640866873065, 0.6333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.49742002063983487, 0.6333333333333333, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13, 0, 0]'),
#  Text(0.5170278637770898, 0.7, 'X[9] <= 0.83\ngini = 0.645\nsamples = 28\nvalue = [0, 1, 4, 14, 8, 1]'),
#  Text(0.5056759545923633, 0.6333333333333333, 'X[8] <= 3.03\ngini = 0.563\nsamples = 23\nvalue = [0, 0, 3, 14, 5, 1]'),
#  Text(0.4953560371517028, 0.5666666666666667, 'X[11] <= 563.5\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 0, 1, 4, 1]'),
#  Text(0.49122807017543857, 0.5, 'X[9] <= 0.805\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.4871001031991744, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4953560371517028, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.49948400412796695, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.5159958720330238, 0.5666666666666667, 'X[3] <= 4.5\ngini = 0.381\nsamples = 17\nvalue = [0, 0, 3, 13, 1, 0]'),
#  Text(0.5118679050567595, 0.5, 'X[4] <= 0.096\ngini = 0.305\nsamples = 16\nvalue = [0, 0, 3, 13, 0, 0]'),
#  Text(0.5036119711042312, 0.43333333333333335, 'X[6] <= 70.5\ngini = 0.142\nsamples = 13\nvalue = [0, 0, 1, 12, 0, 0]'),
#  Text(0.49948400412796695, 0.36666666666666664, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.5077399380804953, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5201238390092879, 0.43333333333333335, 'X[3] <= 2.35\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.5159958720330238, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5242518059855521, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.5201238390092879, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5283797729618163, 0.6333333333333333, 'X[11] <= 360.5\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 1, 0, 3, 0]'),
#  Text(0.5242518059855521, 0.5666666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.5325077399380805, 0.5666666666666667, 'X[2] <= 0.535\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.5283797729618163, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5366357069143447, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7327302631578947, 0.9, 'X[1] <= 0.375\ngini = 0.649\nsamples = 367\nvalue = [1, 8, 62, 182, 100, 14]'),
#  Text(0.6202270381836945, 0.8333333333333334, 'X[6] <= 43.5\ngini = 0.612\nsamples = 117\nvalue = [0, 0, 10, 41, 59, 7]'),
#  Text(0.586171310629515, 0.7666666666666667, 'X[2] <= 0.485\ngini = 0.566\nsamples = 83\nvalue = [0, 0, 5, 23, 49, 6]'),
#  Text(0.5593395252837977, 0.7, 'X[2] <= 0.295\ngini = 0.476\nsamples = 58\nvalue = [0, 0, 3, 12, 40, 3]'),
#  Text(0.5552115583075335, 0.6333333333333333, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.5634674922600619, 0.6333333333333333, 'X[11] <= 350.5\ngini = 0.438\nsamples = 55\nvalue = [0, 0, 3, 9, 40, 3]'),
#  Text(0.5593395252837977, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.5675954592363261, 0.5666666666666667, 'X[11] <= 1300.5\ngini = 0.398\nsamples = 53\nvalue = [0, 0, 3, 9, 40, 1]'),
#  Text(0.544891640866873, 0.5, 'X[8] <= 3.125\ngini = 0.256\nsamples = 41\nvalue = [0, 0, 1, 5, 35, 0]'),
#  Text(0.5407636738906089, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5490196078431373, 0.43333333333333335, 'X[6] <= 7.0\ngini = 0.224\nsamples = 40\nvalue = [0, 0, 1, 4, 35, 0]'),
#  Text(0.544891640866873, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5531475748194015, 0.36666666666666664, 'X[7] <= 0.994\ngini = 0.188\nsamples = 39\nvalue = [0, 0, 1, 3, 35, 0]'),
#  Text(0.544891640866873, 0.3, 'X[7] <= 0.994\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 0, 2, 4, 0]'),
#  Text(0.5407636738906089, 0.23333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.5490196078431373, 0.23333333333333334, 'X[9] <= 0.7\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.544891640866873, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5531475748194015, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5614035087719298, 0.3, 'X[8] <= 3.32\ngini = 0.116\nsamples = 33\nvalue = [0, 0, 1, 1, 31, 0]'),
#  Text(0.5572755417956656, 0.23333333333333334, 'gini = 0.0\nsamples = 24\nvalue = [0, 0, 0, 0, 24, 0]'),
#  Text(0.5655314757481941, 0.23333333333333334, 'X[9] <= 0.865\ngini = 0.37\nsamples = 9\nvalue = [0, 0, 1, 1, 7, 0]'),
#  Text(0.5614035087719298, 0.16666666666666666, 'X[6] <= 35.0\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 0, 7, 0]'),
#  Text(0.5572755417956656, 0.1, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.5655314757481941, 0.1, 'X[2] <= 0.365\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.5614035087719298, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5696594427244582, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5696594427244582, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5902992776057792, 0.5, 'X[9] <= 0.815\ngini = 0.681\nsamples = 12\nvalue = [0, 0, 2, 4, 5, 1]'),
#  Text(0.586171310629515, 0.43333333333333335, 'X[9] <= 0.715\ngini = 0.617\nsamples = 9\nvalue = [0, 0, 2, 1, 5, 1]'),
#  Text(0.5820433436532507, 0.36666666666666664, 'X[2] <= 0.375\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 0, 1]'),
#  Text(0.5779153766769866, 0.3, 'X[8] <= 3.3\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.5737874097007224, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.5820433436532507, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.586171310629515, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.5902992776057792, 0.36666666666666664, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.5944272445820433, 0.43333333333333335, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.6130030959752322, 0.7, 'X[3] <= 2.55\ngini = 0.656\nsamples = 25\nvalue = [0, 0, 2, 11, 9, 3]'),
#  Text(0.5985552115583075, 0.6333333333333333, 'X[11] <= 423.0\ngini = 0.298\nsamples = 11\nvalue = [0, 0, 0, 9, 2, 0]'),
#  Text(0.5944272445820433, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.6026831785345718, 0.5666666666666667, 'X[8] <= 3.085\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 0, 9, 1, 0]'),
#  Text(0.5985552115583075, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.6068111455108359, 0.5, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.6274509803921569, 0.6333333333333333, 'X[11] <= 1011.0\ngini = 0.663\nsamples = 14\nvalue = [0, 0, 2, 2, 7, 3]'),
#  Text(0.6233230134158927, 0.5666666666666667, 'X[6] <= 19.5\ngini = 0.569\nsamples = 12\nvalue = [0, 0, 0, 2, 7, 3]'),
#  Text(0.6150670794633643, 0.5, 'X[7] <= 0.996\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 0, 1, 3]'),
#  Text(0.6109391124871001, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.6191950464396285, 0.43333333333333335, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3]'),
#  Text(0.631578947368421, 0.5, 'X[11] <= 554.0\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 0, 2, 6, 0]'),
#  Text(0.6274509803921569, 0.43333333333333335, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.6357069143446853, 0.43333333333333335, 'X[10] <= 12.05\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.631578947368421, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.6398348813209495, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.631578947368421, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.6542827657378741, 0.7666666666666667, 'X[3] <= 2.05\ngini = 0.611\nsamples = 34\nvalue = [0, 0, 5, 18, 10, 1]'),
#  Text(0.6398348813209495, 0.7, 'X[5] <= 41.5\ngini = 0.255\nsamples = 14\nvalue = [0, 0, 0, 12, 1, 1]'),
#  Text(0.6357069143446853, 0.6333333333333333, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.6439628482972136, 0.6333333333333333, 'X[7] <= 0.995\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.6398348813209495, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.6480908152734778, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.6687306501547987, 0.7, 'X[7] <= 0.996\ngini = 0.645\nsamples = 20\nvalue = [0, 0, 5, 6, 9, 0]'),
#  Text(0.6604747162022704, 0.6333333333333333, 'X[1] <= 0.22\ngini = 0.426\nsamples = 13\nvalue = [0, 0, 0, 4, 9, 0]'),
#  Text(0.6563467492260062, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.6646026831785345, 0.5666666666666667, 'X[5] <= 21.5\ngini = 0.298\nsamples = 11\nvalue = [0, 0, 0, 2, 9, 0]'),
#  Text(0.6604747162022704, 0.5, 'X[10] <= 11.55\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.6563467492260062, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.6646026831785345, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.6687306501547987, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 8, 0]'),
#  Text(0.6769865841073271, 0.6333333333333333, 'X[1] <= 0.345\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]'),
#  Text(0.672858617131063, 0.5666666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.6811145510835913, 0.5666666666666667, 'X[0] <= 7.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.6769865841073271, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6852425180598555, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.845233488132095, 0.8333333333333334, 'X[9] <= 0.585\ngini = 0.61\nsamples = 250\nvalue = [1, 8, 52, 141, 41, 7]'),
#  Text(0.7502579979360166, 0.7666666666666667, 'X[5] <= 8.5\ngini = 0.63\nsamples = 77\nvalue = [1, 7, 30, 35, 4, 0]'),
#  Text(0.7223942208462333, 0.7, 'X[8] <= 3.365\ngini = 0.602\nsamples = 34\nvalue = [1, 4, 19, 9, 1, 0]'),
#  Text(0.7058823529411765, 0.6333333333333333, 'X[0] <= 9.65\ngini = 0.583\nsamples = 12\nvalue = [0, 1, 3, 7, 1, 0]'),
#  Text(0.6976264189886481, 0.5666666666666667, 'X[1] <= 0.812\ngini = 0.219\nsamples = 8\nvalue = [0, 1, 0, 7, 0, 0]'),
#  Text(0.6934984520123839, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.7017543859649122, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.7141382868937048, 0.5666666666666667, 'X[8] <= 3.2\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 0, 1, 0]'),
#  Text(0.7100103199174407, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.718266253869969, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7389060887512899, 0.6333333333333333, 'X[6] <= 10.0\ngini = 0.442\nsamples = 22\nvalue = [1, 3, 16, 2, 0, 0]'),
#  Text(0.7306501547987616, 0.5666666666666667, 'X[11] <= 1064.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0, 0, 0]'),
#  Text(0.7265221878224974, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.7347781217750258, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.7471620227038184, 0.5666666666666667, 'X[8] <= 3.755\ngini = 0.277\nsamples = 19\nvalue = [0, 1, 16, 2, 0, 0]'),
#  Text(0.7430340557275542, 0.5, 'X[3] <= 2.05\ngini = 0.198\nsamples = 18\nvalue = [0, 0, 16, 2, 0, 0]'),
#  Text(0.7389060887512899, 0.43333333333333335, 'X[3] <= 1.75\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(0.7347781217750258, 0.36666666666666664, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.7430340557275542, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7471620227038184, 0.43333333333333335, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(0.7512899896800825, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.7781217750257998, 0.7, 'X[1] <= 1.0\ngini = 0.559\nsamples = 43\nvalue = [0, 3, 11, 26, 3, 0]'),
#  Text(0.7739938080495357, 0.6333333333333333, 'X[10] <= 11.15\ngini = 0.496\nsamples = 40\nvalue = [0, 0, 11, 26, 3, 0]'),
#  Text(0.7636738906088751, 0.5666666666666667, 'X[10] <= 10.85\ngini = 0.498\nsamples = 15\nvalue = [0, 0, 8, 7, 0, 0]'),
#  Text(0.759545923632611, 0.5, 'X[1] <= 0.575\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 2, 7, 0, 0]'),
#  Text(0.7554179566563467, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.7636738906088751, 0.43333333333333335, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.7678018575851393, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.7843137254901961, 0.5666666666666667, 'X[8] <= 3.485\ngini = 0.394\nsamples = 25\nvalue = [0, 0, 3, 19, 3, 0]'),
#  Text(0.7760577915376677, 0.5, 'X[5] <= 9.5\ngini = 0.117\nsamples = 16\nvalue = [0, 0, 0, 15, 1, 0]'),
#  Text(0.7719298245614035, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7801857585139319, 0.43333333333333335, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 0, 15, 0, 0]'),
#  Text(0.7925696594427245, 0.5, 'X[7] <= 0.994\ngini = 0.642\nsamples = 9\nvalue = [0, 0, 3, 4, 2, 0]'),
#  Text(0.7884416924664602, 0.43333333333333335, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.7966976264189887, 0.43333333333333335, 'X[5] <= 29.5\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 0, 4, 2, 0]'),
#  Text(0.7925696594427245, 0.36666666666666664, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.8008255933952528, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.782249742002064, 0.6333333333333333, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.9402089783281734, 0.7666666666666667, 'X[6] <= 73.5\ngini = 0.561\nsamples = 173\nvalue = [0, 1, 22, 106, 37, 7]'),
#  Text(0.9010577915376677, 0.7, 'X[11] <= 1076.0\ngini = 0.505\nsamples = 154\nvalue = [0, 1, 14, 103, 30, 6]'),
#  Text(0.8599071207430341, 0.6333333333333333, 'X[9] <= 0.685\ngini = 0.598\nsamples = 82\nvalue = [0, 0, 9, 44, 26, 3]'),
#  Text(0.8255933952528379, 0.5666666666666667, 'X[4] <= 0.099\ngini = 0.414\nsamples = 31\nvalue = [0, 0, 3, 23, 5, 0]'),
#  Text(0.8173374613003096, 0.5, 'X[11] <= 1065.5\ngini = 0.226\nsamples = 24\nvalue = [0, 0, 1, 21, 2, 0]'),
#  Text(0.8132094943240454, 0.43333333333333335, 'X[3] <= 5.15\ngini = 0.159\nsamples = 23\nvalue = [0, 0, 0, 21, 2, 0]'),
#  Text(0.8090815273477813, 0.36666666666666664, 'X[7] <= 1.0\ngini = 0.087\nsamples = 22\nvalue = [0, 0, 0, 21, 1, 0]'),
#  Text(0.804953560371517, 0.3, 'gini = 0.0\nsamples = 18\nvalue = [0, 0, 0, 18, 0, 0]'),
#  Text(0.8132094943240454, 0.3, 'X[4] <= 0.089\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.8090815273477813, 0.23333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8173374613003096, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8173374613003096, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8214654282765738, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8338493292053664, 0.5, 'X[11] <= 429.0\ngini = 0.653\nsamples = 7\nvalue = [0, 0, 2, 2, 3, 0]'),
#  Text(0.8297213622291022, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8379772961816305, 0.43333333333333335, 'X[8] <= 3.215\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 2, 0, 3, 0]'),
#  Text(0.8338493292053664, 0.36666666666666664, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.8421052631578947, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8942208462332302, 0.5666666666666667, 'X[7] <= 0.999\ngini = 0.644\nsamples = 51\nvalue = [0, 0, 6, 21, 21, 3]'),
#  Text(0.8740970072239422, 0.5, 'X[3] <= 2.15\ngini = 0.625\nsamples = 42\nvalue = [0, 0, 4, 14, 21, 3]'),
#  Text(0.8544891640866873, 0.43333333333333335, 'X[2] <= 0.045\ngini = 0.597\nsamples = 12\nvalue = [0, 0, 1, 7, 2, 2]'),
#  Text(0.8503611971104231, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8586171310629515, 0.36666666666666664, 'X[1] <= 0.425\ngini = 0.46\nsamples = 10\nvalue = [0, 0, 1, 7, 0, 2]'),
#  Text(0.8544891640866873, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.8627450980392157, 0.3, 'X[4] <= 0.104\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]'),
#  Text(0.8586171310629515, 0.23333333333333334, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.8668730650154799, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8937048503611971, 0.43333333333333335, 'X[8] <= 3.335\ngini = 0.533\nsamples = 30\nvalue = [0, 0, 3, 7, 19, 1]'),
#  Text(0.8895768833849329, 0.36666666666666664, 'X[10] <= 11.45\ngini = 0.65\nsamples = 20\nvalue = [0, 0, 3, 7, 9, 1]'),
#  Text(0.8792569659442725, 0.3, 'X[0] <= 8.75\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 2, 5, 0, 0]'),
#  Text(0.8751289989680082, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8833849329205367, 0.23333333333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.8998968008255934, 0.3, 'X[6] <= 18.5\ngini = 0.485\nsamples = 13\nvalue = [0, 0, 1, 2, 9, 1]'),
#  Text(0.891640866873065, 0.23333333333333334, 'X[6] <= 14.5\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 2, 1, 0]'),
#  Text(0.8875128998968008, 0.16666666666666666, 'X[1] <= 0.485\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.8833849329205367, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.891640866873065, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8957688338493293, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9081527347781218, 0.23333333333333334, 'X[2] <= 0.665\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 0, 0, 8, 1]'),
#  Text(0.9040247678018576, 0.16666666666666666, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 8, 0]'),
#  Text(0.9122807017543859, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.8978328173374613, 0.36666666666666664, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 0, 10, 0]'),
#  Text(0.9143446852425181, 0.5, 'X[5] <= 24.0\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 2, 7, 0, 0]'),
#  Text(0.9102167182662538, 0.43333333333333335, 'X[0] <= 14.05\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]'),
#  Text(0.9060887512899897, 0.36666666666666664, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.9143446852425181, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9184726522187823, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9422084623323014, 0.6333333333333333, 'X[6] <= 12.5\ngini = 0.319\nsamples = 72\nvalue = [0, 1, 5, 59, 4, 3]'),
#  Text(0.9339525283797729, 0.5666666666666667, 'X[8] <= 3.355\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1]'),
#  Text(0.9298245614035088, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9380804953560371, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9504643962848297, 0.5666666666666667, 'X[3] <= 5.3\ngini = 0.282\nsamples = 70\nvalue = [0, 1, 4, 59, 4, 2]'),
#  Text(0.9463364293085655, 0.5, 'X[10] <= 10.575\ngini = 0.263\nsamples = 69\nvalue = [0, 1, 4, 59, 3, 2]'),
#  Text(0.9422084623323014, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9504643962848297, 0.43333333333333335, 'X[10] <= 12.7\ngini = 0.242\nsamples = 68\nvalue = [0, 1, 4, 59, 2, 2]'),
#  Text(0.934984520123839, 0.36666666666666664, 'X[11] <= 1422.5\ngini = 0.203\nsamples = 64\nvalue = [0, 1, 3, 57, 2, 1]'),
#  Text(0.9205366357069144, 0.3, 'X[8] <= 3.695\ngini = 0.046\nsamples = 42\nvalue = [0, 0, 0, 41, 1, 0]'),
#  Text(0.9164086687306502, 0.23333333333333334, 'gini = 0.0\nsamples = 38\nvalue = [0, 0, 0, 38, 0, 0]'),
#  Text(0.9246646026831785, 0.23333333333333334, 'X[10] <= 12.4\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.9205366357069144, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9287925696594427, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9494324045407637, 0.3, 'X[11] <= 1451.5\ngini = 0.446\nsamples = 22\nvalue = [0, 1, 3, 16, 1, 1]'),
#  Text(0.9411764705882353, 0.23333333333333334, 'X[6] <= 30.0\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 1, 0, 0, 1]'),
#  Text(0.9370485036119711, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9453044375644994, 0.16666666666666666, 'X[5] <= 20.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.9411764705882353, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9494324045407637, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.957688338493292, 0.23333333333333334, 'X[7] <= 0.994\ngini = 0.277\nsamples = 19\nvalue = [0, 0, 2, 16, 1, 0]'),
#  Text(0.9535603715170279, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9618163054695562, 0.16666666666666666, 'X[0] <= 6.25\ngini = 0.198\nsamples = 18\nvalue = [0, 0, 2, 16, 0, 0]'),
#  Text(0.957688338493292, 0.1, 'X[6] <= 26.5\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 2, 3, 0, 0]'),
#  Text(0.9535603715170279, 0.03333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.9618163054695562, 0.03333333333333333, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9659442724458205, 0.1, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13, 0, 0]'),
#  Text(0.9659442724458205, 0.36666666666666664, 'X[2] <= 0.215\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 2, 0, 1]'),
#  Text(0.9618163054695562, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9700722394220846, 0.3, 'X[3] <= 2.3\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1]'),
#  Text(0.9659442724458205, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9742002063983488, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9545923632610939, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9793601651186791, 0.7, 'X[9] <= 0.835\ngini = 0.659\nsamples = 19\nvalue = [0, 0, 8, 3, 7, 1]'),
#  Text(0.9752321981424149, 0.6333333333333333, 'X[1] <= 0.49\ngini = 0.556\nsamples = 13\nvalue = [0, 0, 8, 3, 1, 1]'),
#  Text(0.9669762641898865, 0.5666666666666667, 'X[6] <= 95.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.9628482972136223, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9711042311661506, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9834881320949432, 0.5666666666666667, 'X[3] <= 1.5\ngini = 0.34\nsamples = 10\nvalue = [0, 0, 8, 1, 0, 1]'),
#  Text(0.9793601651186791, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9876160990712074, 0.5, 'X[9] <= 0.735\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 8, 1, 0, 0]'),
#  Text(0.9834881320949432, 0.43333333333333335, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.9917440660474717, 0.43333333333333335, 'X[0] <= 11.1\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.9876160990712074, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9958720330237358, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9834881320949432, 0.6333333333333333, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]')]

# %%
# Taking 20 data set for practice you can take less also
df1=df.head(500)
df1
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.4             0.700         0.00             1.9      0.076
# 1              7.8             0.880         0.00             2.6      0.098
# 2              7.8             0.760         0.04             2.3      0.092
# 3             11.2             0.280         0.56             1.9      0.075
# 4              7.4             0.700         0.00             1.9      0.076
# ..             ...               ...          ...             ...        ...
# 495            9.4             0.615         0.28             3.2      0.087
# 496           11.8             0.380         0.55             2.1      0.071
# 497           10.6             1.020         0.43             2.9      0.076
# 498            7.0             0.650         0.02             2.1      0.066
# 499            7.0             0.640         0.02             2.1      0.067
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   11.0                  34.0   0.9978  3.51       0.56
# 1                   25.0                  67.0   0.9968  3.20       0.68
# 2                   15.0                  54.0   0.9970  3.26       0.65
# 3                   17.0                  60.0   0.9980  3.16       0.58
# 4                   11.0                  34.0   0.9978  3.51       0.56
# ..                   ...                   ...      ...   ...        ...
# 495                 18.0                  72.0   1.0001  3.31       0.53
# 496                  5.0                  19.0   0.9986  3.11       0.62
# 497                 26.0                  88.0   0.9984  3.08       0.57
# 498                  8.0                  25.0   0.9972  3.47       0.67
# 499                  9.0                  23.0   0.9970  3.47       0.67
#
#      alcohol  quality   Id
# 0        9.4        5    0
# 1        9.8        5    1
# 2        9.8        5    2
# 3        9.8        6    3
# 4        9.4        5    4
# ..       ...      ...  ...
# 495      9.7        5  698
# 496     10.8        6  699
# 497     10.1        6  700
# 498      9.5        6  701
# 499      9.4        6  702
#
# [500 rows x 13 columns]

# %%
# dependent and independent columns
X1=df1.drop(columns=["quality"])
y1=df1['quality']

# %%
# Unique class
set(y1)
# Out:
# {3, 4, 5, 6, 7, 8}

# %%
dt_model=DecisionTreeClassifier()
dt_model.fit(X1,y1)
# Out:
# DecisionTreeClassifier()

# %%
X1
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.4             0.700         0.00             1.9      0.076
# 1              7.8             0.880         0.00             2.6      0.098
# 2              7.8             0.760         0.04             2.3      0.092
# 3             11.2             0.280         0.56             1.9      0.075
# 4              7.4             0.700         0.00             1.9      0.076
# ..             ...               ...          ...             ...        ...
# 495            9.4             0.615         0.28             3.2      0.087
# 496           11.8             0.380         0.55             2.1      0.071
# 497           10.6             1.020         0.43             2.9      0.076
# 498            7.0             0.650         0.02             2.1      0.066
# 499            7.0             0.640         0.02             2.1      0.067
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   11.0                  34.0   0.9978  3.51       0.56
# 1                   25.0                  67.0   0.9968  3.20       0.68
# 2                   15.0                  54.0   0.9970  3.26       0.65
# 3                   17.0                  60.0   0.9980  3.16       0.58
# 4                   11.0                  34.0   0.9978  3.51       0.56
# ..                   ...                   ...      ...   ...        ...
# 495                 18.0                  72.0   1.0001  3.31       0.53
# 496                  5.0                  19.0   0.9986  3.11       0.62
# 497                 26.0                  88.0   0.9984  3.08       0.57
# 498                  8.0                  25.0   0.9972  3.47       0.67
# 499                  9.0                  23.0   0.9970  3.47       0.67
#
#      alcohol   Id
# 0        9.4    0
# 1        9.8    1
# 2        9.8    2
# 3        9.8    3
# 4        9.4    4
# ..       ...  ...
# 495      9.7  698
# 496     10.8  699
# 497     10.1  700
# 498      9.5  701
# 499      9.4  702
#
# [500 rows x 12 columns]

# %%
(0.076+0.075)/2
# Out:
# 0.0755

# %%
l=X1["sulphates"]
(l[6]+l[7])/2
# Out:
# 0.46499999999999997

# %%
y1
# Out:
# 0      5
# 1      5
# 2      5
# 3      6
# 4      5
#       ..
# 495    5
# 496    6
# 497    6
# 498    6
# 499    6
# Name: quality, Length: 500, dtype: int64

# %%
plt.figure(figsize=(20,30))
tree.plot_tree(dt_model,filled=True, class_names=[str(i) for i in set(y1)],feature_names=X1.columns)
# plt.savefig("Dt_model1")
# Out:
# [Text(0.450098167539267, 0.96875, 'alcohol <= 9.75\ngini = 0.629\nsamples = 500\nvalue = [2, 16, 235, 186, 52, 9]\nclass = 5'),
#  Text(0.1863001745200698, 0.90625, 'sulphates <= 0.575\ngini = 0.471\nsamples = 228\nvalue = [2, 9, 155, 58, 4, 0]\nclass = 5'),
#  Text(0.08376963350785341, 0.84375, 'density <= 1.001\ngini = 0.283\nsamples = 88\nvalue = [1, 5, 74, 7, 1, 0]\nclass = 5'),
#  Text(0.07678883071553229, 0.78125, 'total sulfur dioxide <= 8.5\ngini = 0.267\nsamples = 87\nvalue = [0, 5, 74, 7, 1, 0]\nclass = 5'),
#  Text(0.06980802792321117, 0.71875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.08376963350785341, 0.71875, 'pH <= 3.55\ngini = 0.251\nsamples = 86\nvalue = [0, 4, 74, 7, 1, 0]\nclass = 5'),
#  Text(0.07678883071553229, 0.65625, 'chlorides <= 0.075\ngini = 0.235\nsamples = 85\nvalue = [0, 4, 74, 6, 1, 0]\nclass = 5'),
#  Text(0.031413612565445025, 0.59375, 'alcohol <= 9.05\ngini = 0.435\nsamples = 26\nvalue = [0, 2, 19, 4, 1, 0]\nclass = 5'),
#  Text(0.013961605584642234, 0.53125, 'total sulfur dioxide <= 39.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]\nclass = 4'),
#  Text(0.006980802792321117, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.020942408376963352, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.04886561954624782, 0.53125, 'volatile acidity <= 0.54\ngini = 0.354\nsamples = 24\nvalue = [0, 1, 19, 3, 1, 0]\nclass = 5'),
#  Text(0.034904013961605584, 0.46875, 'free sulfur dioxide <= 8.0\ngini = 0.594\nsamples = 8\nvalue = [0, 1, 4, 3, 0, 0]\nclass = 5'),
#  Text(0.027923211169284468, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.041884816753926704, 0.40625, 'fixed acidity <= 9.35\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 1, 3, 0, 0]\nclass = 6'),
#  Text(0.034904013961605584, 0.34375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.04886561954624782, 0.34375, 'chlorides <= 0.065\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]\nclass = 4'),
#  Text(0.041884816753926704, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.055846422338568937, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.06282722513089005, 0.46875, 'sulphates <= 0.565\ngini = 0.117\nsamples = 16\nvalue = [0, 0, 15, 0, 1, 0]\nclass = 5'),
#  Text(0.055846422338568937, 0.40625, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0, 0, 0]\nclass = 5'),
#  Text(0.06980802792321117, 0.40625, 'citric acid <= 0.125\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]\nclass = 5'),
#  Text(0.06282722513089005, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.07678883071553229, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.12216404886561955, 0.59375, 'residual sugar <= 4.35\ngini = 0.129\nsamples = 59\nvalue = [0, 2, 55, 2, 0, 0]\nclass = 5'),
#  Text(0.10471204188481675, 0.53125, 'residual sugar <= 1.65\ngini = 0.101\nsamples = 57\nvalue = [0, 2, 54, 1, 0, 0]\nclass = 5'),
#  Text(0.09075043630017451, 0.46875, 'chlorides <= 0.086\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]\nclass = 5'),
#  Text(0.08376963350785341, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.09773123909249563, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.11867364746945899, 0.46875, 'Id <= 77.5\ngini = 0.071\nsamples = 54\nvalue = [0, 2, 52, 0, 0, 0]\nclass = 5'),
#  Text(0.11169284467713787, 0.40625, 'citric acid <= 0.255\ngini = 0.298\nsamples = 11\nvalue = [0, 2, 9, 0, 0, 0]\nclass = 5'),
#  Text(0.10471204188481675, 0.34375, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]\nclass = 5'),
#  Text(0.11867364746945899, 0.34375, 'total sulfur dioxide <= 82.5\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0, 0, 0]\nclass = 4'),
#  Text(0.11169284467713787, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.1256544502617801, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.1256544502617801, 0.40625, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43, 0, 0, 0]\nclass = 5'),
#  Text(0.13961605584642234, 0.53125, 'fixed acidity <= 8.35\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.13263525305410123, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.14659685863874344, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.09075043630017451, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.09075043630017451, 0.78125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]\nclass = 3'),
#  Text(0.28883071553228623, 0.84375, 'total sulfur dioxide <= 39.0\ngini = 0.531\nsamples = 140\nvalue = [1, 4, 81, 51, 3, 0]\nclass = 5'),
#  Text(0.225130890052356, 0.78125, 'Id <= 489.5\ngini = 0.554\nsamples = 65\nvalue = [1, 1, 24, 36, 3, 0]\nclass = 6'),
#  Text(0.20593368237347295, 0.71875, 'fixed acidity <= 11.1\ngini = 0.58\nsamples = 42\nvalue = [0, 1, 21, 17, 3, 0]\nclass = 5'),
#  Text(0.18848167539267016, 0.65625, 'pH <= 3.285\ngini = 0.528\nsamples = 36\nvalue = [0, 1, 21, 13, 1, 0]\nclass = 5'),
#  Text(0.17452006980802792, 0.59375, 'chlorides <= 0.182\ngini = 0.41\nsamples = 20\nvalue = [0, 1, 15, 3, 1, 0]\nclass = 5'),
#  Text(0.16753926701570682, 0.53125, 'volatile acidity <= 0.265\ngini = 0.296\nsamples = 18\nvalue = [0, 1, 15, 1, 1, 0]\nclass = 5'),
#  Text(0.16055846422338568, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.17452006980802792, 0.46875, 'chlorides <= 0.067\ngini = 0.215\nsamples = 17\nvalue = [0, 1, 15, 0, 1, 0]\nclass = 5'),
#  Text(0.16753926701570682, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.18150087260034903, 0.40625, 'sulphates <= 1.07\ngini = 0.117\nsamples = 16\nvalue = [0, 1, 15, 0, 0, 0]\nclass = 5'),
#  Text(0.17452006980802792, 0.34375, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0, 0, 0]\nclass = 5'),
#  Text(0.18848167539267016, 0.34375, 'chlorides <= 0.093\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]\nclass = 4'),
#  Text(0.18150087260034903, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.19546247818499127, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.18150087260034903, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.2024432809773124, 0.59375, 'alcohol <= 9.45\ngini = 0.469\nsamples = 16\nvalue = [0, 0, 6, 10, 0, 0]\nclass = 6'),
#  Text(0.19546247818499127, 0.53125, 'free sulfur dioxide <= 4.5\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 1, 10, 0, 0]\nclass = 6'),
#  Text(0.18848167539267016, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.2024432809773124, 0.46875, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]\nclass = 6'),
#  Text(0.2094240837696335, 0.53125, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]\nclass = 5'),
#  Text(0.22338568935427575, 0.65625, 'free sulfur dioxide <= 8.0\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 0, 4, 2, 0]\nclass = 6'),
#  Text(0.2164048865619546, 0.59375, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(0.23036649214659685, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.2443280977312391, 0.71875, 'chlorides <= 0.086\ngini = 0.299\nsamples = 23\nvalue = [1, 0, 3, 19, 0, 0]\nclass = 6'),
#  Text(0.23734729493891799, 0.65625, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 0, 15, 0, 0]\nclass = 6'),
#  Text(0.2513089005235602, 0.65625, 'sulphates <= 0.615\ngini = 0.594\nsamples = 8\nvalue = [1, 0, 3, 4, 0, 0]\nclass = 6'),
#  Text(0.2443280977312391, 0.59375, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(0.2582897033158813, 0.59375, 'density <= 0.999\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.2513089005235602, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.26527050610820246, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]\nclass = 3'),
#  Text(0.3525305410122164, 0.78125, 'fixed acidity <= 9.95\ngini = 0.381\nsamples = 75\nvalue = [0, 3, 57, 15, 0, 0]\nclass = 5'),
#  Text(0.32809773123909247, 0.71875, 'pH <= 3.315\ngini = 0.318\nsamples = 69\nvalue = [0, 3, 56, 10, 0, 0]\nclass = 5'),
#  Text(0.30017452006980805, 0.65625, 'sulphates <= 1.46\ngini = 0.192\nsamples = 48\nvalue = [0, 2, 43, 3, 0, 0]\nclass = 5'),
#  Text(0.2862129144851658, 0.59375, 'volatile acidity <= 0.325\ngini = 0.124\nsamples = 46\nvalue = [0, 1, 43, 2, 0, 0]\nclass = 5'),
#  Text(0.2792321116928447, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.2931937172774869, 0.53125, 'residual sugar <= 1.55\ngini = 0.086\nsamples = 45\nvalue = [0, 1, 43, 1, 0, 0]\nclass = 5'),
#  Text(0.2792321116928447, 0.46875, 'total sulfur dioxide <= 84.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]\nclass = 4'),
#  Text(0.27225130890052357, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.2862129144851658, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.30715532286212915, 0.46875, 'citric acid <= 0.135\ngini = 0.045\nsamples = 43\nvalue = [0, 0, 42, 1, 0, 0]\nclass = 5'),
#  Text(0.30017452006980805, 0.40625, 'free sulfur dioxide <= 15.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]\nclass = 5'),
#  Text(0.2931937172774869, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.30715532286212915, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.31413612565445026, 0.40625, 'gini = 0.0\nsamples = 40\nvalue = [0, 0, 40, 0, 0, 0]\nclass = 5'),
#  Text(0.31413612565445026, 0.59375, 'Id <= 188.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]\nclass = 4'),
#  Text(0.30715532286212915, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.32111692844677137, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.35602094240837695, 0.65625, 'volatile acidity <= 0.47\ngini = 0.503\nsamples = 21\nvalue = [0, 1, 13, 7, 0, 0]\nclass = 5'),
#  Text(0.34205933682373474, 0.59375, 'pH <= 3.435\ngini = 0.444\nsamples = 9\nvalue = [0, 0, 3, 6, 0, 0]\nclass = 6'),
#  Text(0.33507853403141363, 0.53125, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]\nclass = 6'),
#  Text(0.34904013961605584, 0.53125, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.3699825479930192, 0.59375, 'density <= 0.996\ngini = 0.292\nsamples = 12\nvalue = [0, 1, 10, 1, 0, 0]\nclass = 5'),
#  Text(0.36300174520069806, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.3769633507853403, 0.53125, 'free sulfur dioxide <= 9.5\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 10, 1, 0, 0]\nclass = 5'),
#  Text(0.3699825479930192, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.38394415357766143, 0.46875, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]\nclass = 5'),
#  Text(0.3769633507853403, 0.71875, 'citric acid <= 0.525\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]\nclass = 6'),
#  Text(0.3699825479930192, 0.65625, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]\nclass = 6'),
#  Text(0.38394415357766143, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.7138961605584643, 0.90625, 'volatile acidity <= 0.555\ngini = 0.659\nsamples = 272\nvalue = [0, 7, 80, 128, 48, 9]\nclass = 6'),
#  Text(0.5907504363001745, 0.84375, 'citric acid <= 0.615\ngini = 0.619\nsamples = 163\nvalue = [0, 2, 28, 89, 37, 7]\nclass = 6'),
#  Text(0.5305410122164049, 0.78125, 'total sulfur dioxide <= 64.5\ngini = 0.569\nsamples = 134\nvalue = [0, 2, 22, 82, 22, 6]\nclass = 6'),
#  Text(0.48342059336823734, 0.71875, 'sulphates <= 0.765\ngini = 0.525\nsamples = 110\nvalue = [0, 1, 11, 72, 20, 6]\nclass = 6'),
#  Text(0.43455497382198954, 0.65625, 'pH <= 3.025\ngini = 0.424\nsamples = 66\nvalue = [0, 1, 9, 49, 4, 3]\nclass = 6'),
#  Text(0.42757417102966844, 0.59375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.44153577661431065, 0.59375, 'chlorides <= 0.071\ngini = 0.391\nsamples = 64\nvalue = [0, 1, 9, 49, 2, 3]\nclass = 6'),
#  Text(0.41535776614310643, 0.53125, 'chlorides <= 0.069\ngini = 0.627\nsamples = 13\nvalue = [0, 0, 1, 7, 2, 3]\nclass = 6'),
#  Text(0.39790575916230364, 0.46875, 'residual sugar <= 2.65\ngini = 0.46\nsamples = 10\nvalue = [0, 0, 0, 7, 2, 1]\nclass = 6'),
#  Text(0.38394415357766143, 0.40625, 'alcohol <= 13.4\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 6, 0, 1]\nclass = 6'),
#  Text(0.3769633507853403, 0.34375, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]\nclass = 6'),
#  Text(0.39092495636998253, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.4118673647469459, 0.40625, 'sulphates <= 0.7\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]\nclass = 7'),
#  Text(0.4048865619546248, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.418848167539267, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.4328097731239092, 0.46875, 'residual sugar <= 2.15\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 0, 2]\nclass = 8'),
#  Text(0.4258289703315881, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.4397905759162304, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]\nclass = 8'),
#  Text(0.4677137870855148, 0.53125, 'free sulfur dioxide <= 30.5\ngini = 0.297\nsamples = 51\nvalue = [0, 1, 8, 42, 0, 0]\nclass = 6'),
#  Text(0.4607329842931937, 0.46875, 'volatile acidity <= 0.255\ngini = 0.274\nsamples = 50\nvalue = [0, 1, 7, 42, 0, 0]\nclass = 6'),
#  Text(0.4537521815008726, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.4677137870855148, 0.40625, 'chlorides <= 0.124\ngini = 0.25\nsamples = 49\nvalue = [0, 1, 6, 42, 0, 0]\nclass = 6'),
#  Text(0.4607329842931937, 0.34375, 'density <= 1.0\ngini = 0.223\nsamples = 48\nvalue = [0, 1, 5, 42, 0, 0]\nclass = 6'),
#  Text(0.44153577661431065, 0.28125, 'Id <= 100.0\ngini = 0.168\nsamples = 44\nvalue = [0, 1, 3, 40, 0, 0]\nclass = 6'),
#  Text(0.42408376963350786, 0.21875, 'residual sugar <= 2.05\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.41710296684118675, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.43106457242582896, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.45898778359511344, 0.21875, 'sulphates <= 0.535\ngini = 0.135\nsamples = 42\nvalue = [0, 1, 2, 39, 0, 0]\nclass = 6'),
#  Text(0.44502617801047123, 0.15625, 'fixed acidity <= 9.35\ngini = 0.449\nsamples = 7\nvalue = [0, 1, 1, 5, 0, 0]\nclass = 6'),
#  Text(0.43804537521815007, 0.09375, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]\nclass = 6'),
#  Text(0.45200698080279234, 0.09375, 'total sulfur dioxide <= 17.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]\nclass = 4'),
#  Text(0.44502617801047123, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.45898778359511344, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.47294938917975565, 0.15625, 'free sulfur dioxide <= 28.0\ngini = 0.056\nsamples = 35\nvalue = [0, 0, 1, 34, 0, 0]\nclass = 6'),
#  Text(0.46596858638743455, 0.09375, 'gini = 0.0\nsamples = 32\nvalue = [0, 0, 0, 32, 0, 0]\nclass = 6'),
#  Text(0.4799301919720768, 0.09375, 'Id <= 312.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]\nclass = 6'),
#  Text(0.47294938917975565, 0.03125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.4869109947643979, 0.03125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.4799301919720768, 0.28125, 'density <= 1.001\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]\nclass = 5'),
#  Text(0.47294938917975565, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.4869109947643979, 0.21875, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.47469458987783597, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.47469458987783597, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.5322862129144852, 0.65625, 'Id <= 513.0\ngini = 0.588\nsamples = 44\nvalue = [0, 0, 2, 23, 16, 3]\nclass = 6'),
#  Text(0.525305410122164, 0.59375, 'Id <= 277.5\ngini = 0.619\nsamples = 36\nvalue = [0, 0, 2, 15, 16, 3]\nclass = 7'),
#  Text(0.4956369982547993, 0.53125, 'density <= 1.0\ngini = 0.403\nsamples = 12\nvalue = [0, 0, 0, 9, 2, 1]\nclass = 6'),
#  Text(0.4886561954624782, 0.46875, 'residual sugar <= 1.5\ngini = 0.314\nsamples = 11\nvalue = [0, 0, 0, 9, 1, 1]\nclass = 6'),
#  Text(0.4816753926701571, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.4956369982547993, 0.40625, 'alcohol <= 12.6\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 0, 9, 0, 1]\nclass = 6'),
#  Text(0.4886561954624782, 0.34375, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]\nclass = 6'),
#  Text(0.5026178010471204, 0.34375, 'citric acid <= 0.23\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 0, 1]\nclass = 6'),
#  Text(0.4956369982547993, 0.28125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.5095986038394416, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.5026178010471204, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.5549738219895288, 0.53125, 'free sulfur dioxide <= 20.5\ngini = 0.583\nsamples = 24\nvalue = [0, 0, 2, 6, 14, 2]\nclass = 7'),
#  Text(0.537521815008726, 0.46875, 'total sulfur dioxide <= 17.5\ngini = 0.475\nsamples = 20\nvalue = [0, 0, 1, 3, 14, 2]\nclass = 7'),
#  Text(0.5235602094240838, 0.40625, 'chlorides <= 0.093\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 0, 2]\nclass = 8'),
#  Text(0.5165794066317626, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]\nclass = 8'),
#  Text(0.5305410122164049, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.5514834205933682, 0.40625, 'alcohol <= 13.7\ngini = 0.291\nsamples = 17\nvalue = [0, 0, 0, 3, 14, 0]\nclass = 7'),
#  Text(0.5445026178010471, 0.34375, 'density <= 1.0\ngini = 0.219\nsamples = 16\nvalue = [0, 0, 0, 2, 14, 0]\nclass = 7'),
#  Text(0.537521815008726, 0.28125, 'residual sugar <= 1.95\ngini = 0.124\nsamples = 15\nvalue = [0, 0, 0, 1, 14, 0]\nclass = 7'),
#  Text(0.5305410122164049, 0.21875, 'sulphates <= 1.055\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]\nclass = 7'),
#  Text(0.5235602094240838, 0.15625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.537521815008726, 0.15625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.5445026178010471, 0.21875, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 0, 12, 0]\nclass = 7'),
#  Text(0.5514834205933682, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.5584642233856894, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.5724258289703316, 0.46875, 'density <= 1.0\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]\nclass = 6'),
#  Text(0.5654450261780105, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.5794066317626527, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.5392670157068062, 0.59375, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]\nclass = 6'),
#  Text(0.5776614310645725, 0.71875, 'pH <= 3.27\ngini = 0.608\nsamples = 24\nvalue = [0, 1, 11, 10, 2, 0]\nclass = 5'),
#  Text(0.5602094240837696, 0.65625, 'citric acid <= 0.575\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 8, 0, 0]\nclass = 6'),
#  Text(0.5532286212914486, 0.59375, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]\nclass = 6'),
#  Text(0.5671902268760908, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.5951134380453752, 0.65625, 'alcohol <= 11.25\ngini = 0.516\nsamples = 15\nvalue = [0, 1, 10, 2, 2, 0]\nclass = 5'),
#  Text(0.581151832460733, 0.59375, 'citric acid <= 0.525\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 9, 0, 1, 0]\nclass = 5'),
#  Text(0.5741710296684118, 0.53125, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]\nclass = 5'),
#  Text(0.5881326352530541, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.6090750436300174, 0.59375, 'volatile acidity <= 0.435\ngini = 0.72\nsamples = 5\nvalue = [0, 1, 1, 2, 1, 0]\nclass = 6'),
#  Text(0.6020942408376964, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.6160558464223386, 0.53125, 'fixed acidity <= 4.9\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 1, 0, 1, 0]\nclass = 4'),
#  Text(0.6090750436300174, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.6230366492146597, 0.46875, 'citric acid <= 0.065\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]\nclass = 5'),
#  Text(0.6160558464223386, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.6300174520069808, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.6509598603839442, 0.78125, 'fixed acidity <= 10.55\ngini = 0.63\nsamples = 29\nvalue = [0, 0, 6, 7, 15, 1]\nclass = 7'),
#  Text(0.6369982547993019, 0.71875, 'residual sugar <= 2.3\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 0, 8, 0]\nclass = 7'),
#  Text(0.6300174520069808, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.643979057591623, 0.65625, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 0, 8, 0]\nclass = 7'),
#  Text(0.6649214659685864, 0.71875, 'total sulfur dioxide <= 45.0\ngini = 0.69\nsamples = 20\nvalue = [0, 0, 5, 7, 7, 1]\nclass = 6'),
#  Text(0.6579406631762653, 0.65625, 'volatile acidity <= 0.375\ngini = 0.644\nsamples = 17\nvalue = [0, 0, 2, 7, 7, 1]\nclass = 6'),
#  Text(0.643979057591623, 0.59375, 'alcohol <= 10.3\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 0, 4, 1]\nclass = 7'),
#  Text(0.6369982547993019, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.6509598603839442, 0.53125, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]\nclass = 7'),
#  Text(0.6719022687609075, 0.59375, 'total sulfur dioxide <= 32.5\ngini = 0.569\nsamples = 12\nvalue = [0, 0, 2, 7, 3, 0]\nclass = 6'),
#  Text(0.6649214659685864, 0.53125, 'density <= 0.999\ngini = 0.656\nsamples = 8\nvalue = [0, 0, 2, 3, 3, 0]\nclass = 6'),
#  Text(0.6509598603839442, 0.46875, 'total sulfur dioxide <= 14.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]\nclass = 6'),
#  Text(0.643979057591623, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.6579406631762653, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]\nclass = 6'),
#  Text(0.6788830715532286, 0.46875, 'total sulfur dioxide <= 20.0\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 0, 2, 0]\nclass = 5'),
#  Text(0.6719022687609075, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.6858638743455497, 0.40625, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.6788830715532286, 0.53125, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]\nclass = 6'),
#  Text(0.6719022687609075, 0.65625, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.8370418848167539, 0.84375, 'sulphates <= 0.595\ngini = 0.632\nsamples = 109\nvalue = [0, 5, 52, 39, 11, 2]\nclass = 5'),
#  Text(0.7905759162303665, 0.78125, 'alcohol <= 11.9\ngini = 0.504\nsamples = 56\nvalue = [0, 3, 37, 13, 3, 0]\nclass = 5'),
#  Text(0.7835951134380453, 0.71875, 'residual sugar <= 2.25\ngini = 0.469\nsamples = 54\nvalue = [0, 3, 37, 13, 1, 0]\nclass = 5'),
#  Text(0.7417102966841187, 0.65625, 'total sulfur dioxide <= 48.5\ngini = 0.576\nsamples = 32\nvalue = [0, 3, 18, 10, 1, 0]\nclass = 5'),
#  Text(0.7137870855148342, 0.59375, 'residual sugar <= 1.75\ngini = 0.636\nsamples = 18\nvalue = [0, 2, 7, 8, 1, 0]\nclass = 6'),
#  Text(0.699825479930192, 0.53125, 'volatile acidity <= 0.677\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 0, 1, 0]\nclass = 5'),
#  Text(0.6928446771378709, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.7068062827225131, 0.46875, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.7277486910994765, 0.53125, 'pH <= 3.15\ngini = 0.571\nsamples = 14\nvalue = [0, 2, 4, 8, 0, 0]\nclass = 6'),
#  Text(0.7207678883071553, 0.46875, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]\nclass = 5'),
#  Text(0.7347294938917975, 0.46875, 'volatile acidity <= 0.812\ngini = 0.5\nsamples = 12\nvalue = [0, 2, 2, 8, 0, 0]\nclass = 6'),
#  Text(0.7207678883071553, 0.40625, 'citric acid <= 0.375\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]\nclass = 6'),
#  Text(0.7137870855148342, 0.34375, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]\nclass = 6'),
#  Text(0.7277486910994765, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.7486910994764397, 0.40625, 'chlorides <= 0.076\ngini = 0.625\nsamples = 4\nvalue = [0, 2, 1, 1, 0, 0]\nclass = 4'),
#  Text(0.7417102966841187, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.7556719022687609, 0.34375, 'alcohol <= 10.4\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.7486910994764397, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.7626527050610821, 0.28125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.7696335078534031, 0.59375, 'free sulfur dioxide <= 36.0\ngini = 0.357\nsamples = 14\nvalue = [0, 1, 11, 2, 0, 0]\nclass = 5'),
#  Text(0.7556719022687609, 0.53125, 'chlorides <= 0.102\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 11, 1, 0, 0]\nclass = 5'),
#  Text(0.7486910994764397, 0.46875, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]\nclass = 5'),
#  Text(0.7626527050610821, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.7835951134380453, 0.53125, 'citric acid <= 0.17\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]\nclass = 4'),
#  Text(0.7766143106457243, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.7905759162303665, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.8254799301919721, 0.65625, 'Id <= 695.5\ngini = 0.236\nsamples = 22\nvalue = [0, 0, 19, 3, 0, 0]\nclass = 5'),
#  Text(0.8184991273996509, 0.59375, 'pH <= 3.5\ngini = 0.172\nsamples = 21\nvalue = [0, 0, 19, 2, 0, 0]\nclass = 5'),
#  Text(0.8115183246073299, 0.53125, 'pH <= 3.36\ngini = 0.095\nsamples = 20\nvalue = [0, 0, 19, 1, 0, 0]\nclass = 5'),
#  Text(0.8045375218150087, 0.46875, 'pH <= 3.255\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]\nclass = 5'),
#  Text(0.7975567190226877, 0.40625, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]\nclass = 5'),
#  Text(0.8115183246073299, 0.40625, 'alcohol <= 10.05\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]\nclass = 5'),
#  Text(0.8045375218150087, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.8184991273996509, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.8184991273996509, 0.46875, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0, 0, 0]\nclass = 5'),
#  Text(0.8254799301919721, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.8324607329842932, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.7975567190226877, 0.71875, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.8835078534031413, 0.78125, 'alcohol <= 9.85\ngini = 0.654\nsamples = 53\nvalue = [0, 2, 15, 26, 8, 2]\nclass = 6'),
#  Text(0.8603839441535777, 0.71875, 'pH <= 3.455\ngini = 0.406\nsamples = 8\nvalue = [0, 1, 6, 1, 0, 0]\nclass = 5'),
#  Text(0.8534031413612565, 0.65625, 'total sulfur dioxide <= 47.5\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]\nclass = 5'),
#  Text(0.8464223385689355, 0.59375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.8603839441535777, 0.59375, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]\nclass = 5'),
#  Text(0.8673647469458988, 0.65625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.9066317626527051, 0.71875, 'chlorides <= 0.071\ngini = 0.617\nsamples = 45\nvalue = [0, 1, 9, 25, 8, 2]\nclass = 6'),
#  Text(0.881326352530541, 0.65625, 'density <= 0.997\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 4, 0, 2, 1]\nclass = 5'),
#  Text(0.8743455497382199, 0.59375, 'residual sugar <= 1.65\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 0, 2, 1]\nclass = 7'),
#  Text(0.8673647469458988, 0.53125, 'density <= 0.993\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1]\nclass = 5'),
#  Text(0.8603839441535777, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.8743455497382199, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.881326352530541, 0.53125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]\nclass = 7'),
#  Text(0.8883071553228621, 0.59375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5'),
#  Text(0.9319371727748691, 0.65625, 'residual sugar <= 3.1\ngini = 0.524\nsamples = 38\nvalue = [0, 1, 5, 25, 6, 1]\nclass = 6'),
#  Text(0.9092495636998255, 0.59375, 'chlorides <= 0.091\ngini = 0.218\nsamples = 25\nvalue = [0, 0, 2, 22, 1, 0]\nclass = 6'),
#  Text(0.9022687609075044, 0.53125, 'alcohol <= 11.65\ngini = 0.156\nsamples = 24\nvalue = [0, 0, 1, 22, 1, 0]\nclass = 6'),
#  Text(0.8883071553228621, 0.46875, 'free sulfur dioxide <= 5.5\ngini = 0.087\nsamples = 22\nvalue = [0, 0, 1, 21, 0, 0]\nclass = 6'),
#  Text(0.881326352530541, 0.40625, 'density <= 0.998\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]\nclass = 6'),
#  Text(0.8743455497382199, 0.34375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]\nclass = 6'),
#  Text(0.8883071553228621, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.8952879581151832, 0.40625, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 0, 19, 0, 0]\nclass = 6'),
#  Text(0.9162303664921466, 0.46875, 'pH <= 3.445\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]\nclass = 6'),
#  Text(0.9092495636998255, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]\nclass = 7'),
#  Text(0.9232111692844677, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.9162303664921466, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]\nclass = 5'),
#  Text(0.9546247818499127, 0.59375, 'Id <= 448.5\ngini = 0.734\nsamples = 13\nvalue = [0, 1, 3, 3, 5, 1]\nclass = 7'),
#  Text(0.93717277486911, 0.53125, 'alcohol <= 12.75\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 1, 5, 0]\nclass = 7'),
#  Text(0.9301919720767888, 0.46875, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]\nclass = 7'),
#  Text(0.944153577661431, 0.46875, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.9720767888307156, 0.53125, 'sulphates <= 0.705\ngini = 0.694\nsamples = 7\nvalue = [0, 1, 3, 2, 0, 1]\nclass = 5'),
#  Text(0.9581151832460733, 0.46875, 'fixed acidity <= 10.7\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 0, 1, 0, 1]\nclass = 4'),
#  Text(0.9511343804537522, 0.40625, 'alcohol <= 10.85\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]\nclass = 4'),
#  Text(0.944153577661431, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.9581151832460733, 0.34375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]\nclass = 4'),
#  Text(0.9650959860383944, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]\nclass = 8'),
#  Text(0.9860383944153578, 0.46875, 'volatile acidity <= 0.623\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]\nclass = 5'),
#  Text(0.9790575916230366, 0.40625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]\nclass = 6'),
#  Text(0.9930191972076788, 0.40625, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]\nclass = 5')]

# %% [markdown]
# * the first value indicates the column and the condition on which the root node was selected and further will be splitted
# * the second value gives the gini impurity of the selected node
# * samples gives the number of observations at that point of time present in the node
# * value within the square brackets represents number of observations present in each class(output) i.e. in the above given figure, 1 observations are in class 1, 19 in class 2 , 6 in class 3 and 4 in the class 4.
#
# Then the split was made on the basis of given condition
#
# chlorides<=0.073 is selected by taking average of two values in this case ((l[4]+l[5])/2) i.e (0.076+0.075)/2=0.0755 or 0.076

# %%
dt_model.score(X1,y1)
# Out:
# 1.0

# %%
dt_model.score(X_test,y_test)
# Out:
# 0.7205240174672489

# %%
import sys
sys.version
# Out:
# '3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]'

# %%
# CCPP:- Cost Complexity Pruning Path
# Pruning means removing leaf nodes or restricting some branches
path=dt_model.cost_complexity_pruning_path(X1,y1)
ccp_alpha=path['ccp_alphas']

# %%
path
# Out:
# {'ccp_alphas': array([0.        , 0.00126667, 0.0018    , 0.00186667, 0.001875  ,
#         0.001875  , 0.001875  , 0.00193333, 0.00194286, 0.002     ,
#         0.002     , 0.002     , 0.002     , 0.002     , 0.002     ,
#         0.002     , 0.002     , 0.002     , 0.002     , 0.002     ,
#         0.00219774, 0.00231082, 0.00266667, 0.00266667, 0.00266667,
#         0.00285714, 0.003     , 0.003     , 0.003     , 0.003     ,
#         0.003     , 0.003     , 0.00303333, 0.00307451, 0.00309127,
#         0.0032    , 0.0032    , 0.00325   , 0.00326667, 0.00328182,
#         0.00333333, 0.00333333, 0.00335062, 0.00338   , 0.00342738,
#         0.00345833, 0.0035    , 0.0035    , 0.00355556, 0.00355556,
#         0.00355556, 0.0036    , 0.00363636, 0.00365797, 0.00366667,
#         0.00392727, 0.00392941, 0.00466667, 0.00501569, 0.00502536,
#         0.00533333, 0.00536957, 0.00555691, 0.00573333, 0.0057619 ,
#         0.006     , 0.0060293 , 0.00617512, 0.00622549, 0.00688889,
#         0.00717172, 0.0077974 , 0.00787273, 0.00827537, 0.0089874 ,
#         0.0095605 , 0.00984464, 0.01201318, 0.01259359, 0.01792996,
#         0.01910643, 0.05510282]),
#  'impurities': array([0.        , 0.0038    , 0.0074    , 0.01113333, 0.01488333,
#         0.01863333, 0.02613333, 0.03386667, 0.03775238, 0.03975238,
#         0.04175238, 0.04375238, 0.04575238, 0.04775238, 0.04975238,
#         0.05375238, 0.05575238, 0.05775238, 0.05975238, 0.06375238,
#         0.07693882, 0.08387129, 0.08653796, 0.08920462, 0.09187129,
#         0.09758557, 0.10058557, 0.10358557, 0.10658557, 0.10958557,
#         0.11258557, 0.11858557, 0.12465224, 0.13080126, 0.14625759,
#         0.14945759, 0.15265759, 0.15915759, 0.16569092, 0.17225456,
#         0.17558789, 0.17892123, 0.20237559, 0.20575559, 0.20918297,
#         0.21609963, 0.22309963, 0.23009963, 0.2407663 , 0.24432186,
#         0.24787741, 0.25147741, 0.25511377, 0.25877175, 0.26243841,
#         0.28207478, 0.2899336 , 0.29460027, 0.29961595, 0.30464131,
#         0.30997465, 0.32071378, 0.33182759, 0.33756093, 0.34332283,
#         0.34932283, 0.35535214, 0.3738775 , 0.38632848, 0.39321737,
#         0.40038909, 0.42378129, 0.43165402, 0.45648012, 0.47445491,
#         0.48401541, 0.49386005, 0.50587323, 0.51846682, 0.55432675,
#         0.57343318, 0.628536  ])}

# %%
dt_model2=[]
for ccp in ccp_alpha:
    dt_m=DecisionTreeClassifier(ccp_alpha=ccp)
    dt_m.fit(X1,y1)
    dt_model2.append(dt_m)

# %%
dt_model2
# Out:
# [DecisionTreeClassifier(),
#  DecisionTreeClassifier(ccp_alpha=0.0012666666666666664),
#  DecisionTreeClassifier(ccp_alpha=0.0018000000000000004),
#  DecisionTreeClassifier(ccp_alpha=0.001866666666666667),
#  DecisionTreeClassifier(ccp_alpha=0.001875),
#  DecisionTreeClassifier(ccp_alpha=0.001875),
#  DecisionTreeClassifier(ccp_alpha=0.001875),
#  DecisionTreeClassifier(ccp_alpha=0.001933333333333334),
#  DecisionTreeClassifier(ccp_alpha=0.0019428571428571429),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.002),
#  DecisionTreeClassifier(ccp_alpha=0.0021977401129943505),
#  DecisionTreeClassifier(ccp_alpha=0.0023108225108225116),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666),
#  DecisionTreeClassifier(ccp_alpha=0.0026666666666666666),
#  DecisionTreeClassifier(ccp_alpha=0.0028571428571428567),
#  DecisionTreeClassifier(ccp_alpha=0.003),
#  DecisionTreeClassifier(ccp_alpha=0.003),
#  DecisionTreeClassifier(ccp_alpha=0.003),
#  DecisionTreeClassifier(ccp_alpha=0.003),
#  DecisionTreeClassifier(ccp_alpha=0.003),
#  DecisionTreeClassifier(ccp_alpha=0.003),
#  DecisionTreeClassifier(ccp_alpha=0.003033333333333333),
#  DecisionTreeClassifier(ccp_alpha=0.003074509803921568),
#  DecisionTreeClassifier(ccp_alpha=0.0030912655971479484),
#  DecisionTreeClassifier(ccp_alpha=0.003199999999999999),
#  DecisionTreeClassifier(ccp_alpha=0.0031999999999999993),
#  DecisionTreeClassifier(ccp_alpha=0.00325),
#  DecisionTreeClassifier(ccp_alpha=0.003266666666666667),
#  DecisionTreeClassifier(ccp_alpha=0.0032818181818181818),
#  DecisionTreeClassifier(ccp_alpha=0.0033333333333333335),
#  DecisionTreeClassifier(ccp_alpha=0.0033333333333333335),
#  DecisionTreeClassifier(ccp_alpha=0.0033506234171050073),
#  DecisionTreeClassifier(ccp_alpha=0.003380000000000001),
#  DecisionTreeClassifier(ccp_alpha=0.003427377220480664),
#  DecisionTreeClassifier(ccp_alpha=0.0034583333333333332),
#  DecisionTreeClassifier(ccp_alpha=0.0034999999999999996),
#  DecisionTreeClassifier(ccp_alpha=0.0035),
#  DecisionTreeClassifier(ccp_alpha=0.003555555555555555),
#  DecisionTreeClassifier(ccp_alpha=0.0035555555555555553),
#  DecisionTreeClassifier(ccp_alpha=0.0035555555555555553),
#  DecisionTreeClassifier(ccp_alpha=0.0036000000000000008),
#  DecisionTreeClassifier(ccp_alpha=0.003636363636363637),
#  DecisionTreeClassifier(ccp_alpha=0.003657971014492746),
#  DecisionTreeClassifier(ccp_alpha=0.003666666666666667),
#  DecisionTreeClassifier(ccp_alpha=0.003927272727272728),
#  DecisionTreeClassifier(ccp_alpha=0.003929411764705883),
#  DecisionTreeClassifier(ccp_alpha=0.004666666666666666),
#  DecisionTreeClassifier(ccp_alpha=0.005015686274509809),
#  DecisionTreeClassifier(ccp_alpha=0.005025362318840584),
#  DecisionTreeClassifier(ccp_alpha=0.005333333333333333),
#  DecisionTreeClassifier(ccp_alpha=0.005369565217391304),
#  DecisionTreeClassifier(ccp_alpha=0.005556907820599505),
#  DecisionTreeClassifier(ccp_alpha=0.005733333333333335),
#  DecisionTreeClassifier(ccp_alpha=0.005761904761904767),
#  DecisionTreeClassifier(ccp_alpha=0.0059999999999999915),
#  DecisionTreeClassifier(ccp_alpha=0.006029304029304031),
#  DecisionTreeClassifier(ccp_alpha=0.006175120772946858),
#  DecisionTreeClassifier(ccp_alpha=0.00622549019607843),
#  DecisionTreeClassifier(ccp_alpha=0.006888888888888889),
#  DecisionTreeClassifier(ccp_alpha=0.007171717171717169),
#  DecisionTreeClassifier(ccp_alpha=0.007797402597402597),
#  DecisionTreeClassifier(ccp_alpha=0.007872727272727267),
#  DecisionTreeClassifier(ccp_alpha=0.008275365263667156),
#  DecisionTreeClassifier(ccp_alpha=0.008987396351575472),
#  DecisionTreeClassifier(ccp_alpha=0.009560503264851083),
#  DecisionTreeClassifier(ccp_alpha=0.00984463768115943),
#  DecisionTreeClassifier(ccp_alpha=0.012013180345705837),
#  DecisionTreeClassifier(ccp_alpha=0.012593592225039446),
#  DecisionTreeClassifier(ccp_alpha=0.017929964421543362),
#  DecisionTreeClassifier(ccp_alpha=0.019106427481219324),
#  DecisionTreeClassifier(ccp_alpha=0.05510282146542833)]

# %%
train_score=[i.score(X1,y1) for i in dt_model2]

# %%
test_score=[i.score(X_test,y_test) for i in dt_model2]

# %%
train_score
# Out:
# [1.0,
#  0.998,
#  0.996,
#  0.994,
#  0.986,
#  0.986,
#  0.986,
#  0.982,
#  0.98,
#  0.954,
#  0.954,
#  0.954,
#  0.954,
#  0.954,
#  0.954,
#  0.954,
#  0.954,
#  0.954,
#  0.954,
#  0.954,
#  0.948,
#  0.946,
#  0.94,
#  0.94,
#  0.94,
#  0.936,
#  0.922,
#  0.922,
#  0.924,
#  0.924,
#  0.922,
#  0.922,
#  0.918,
#  0.914,
#  0.904,
#  0.902,
#  0.9,
#  0.896,
#  0.892,
#  0.892,
#  0.88,
#  0.884,
#  0.874,
#  0.872,
#  0.866,
#  0.864,
#  0.86,
#  0.858,
#  0.848,
#  0.854,
#  0.854,
#  0.842,
#  0.84,
#  0.848,
#  0.846,
#  0.846,
#  0.818,
#  0.816,
#  0.816,
#  0.814,
#  0.802,
#  0.804,
#  0.804,
#  0.786,
#  0.782,
#  0.778,
#  0.772,
#  0.76,
#  0.75,
#  0.736,
#  0.734,
#  0.708,
#  0.708,
#  0.686,
#  0.67,
#  0.662,
#  0.654,
#  0.632,
#  0.616,
#  0.592,
#  0.566,
#  0.47]

# %%
test_score
# Out:
# [0.7248908296943232,
#  0.6943231441048034,
#  0.7205240174672489,
#  0.7161572052401747,
#  0.7205240174672489,
#  0.7205240174672489,
#  0.7030567685589519,
#  0.7161572052401747,
#  0.7205240174672489,
#  0.6986899563318777,
#  0.6943231441048034,
#  0.7074235807860262,
#  0.6943231441048034,
#  0.7161572052401747,
#  0.7161572052401747,
#  0.7205240174672489,
#  0.7030567685589519,
#  0.6943231441048034,
#  0.7074235807860262,
#  0.7074235807860262,
#  0.7074235807860262,
#  0.7030567685589519,
#  0.6986899563318777,
#  0.7117903930131004,
#  0.7117903930131004,
#  0.7161572052401747,
#  0.7030567685589519,
#  0.6943231441048034,
#  0.7074235807860262,
#  0.7030567685589519,
#  0.6986899563318777,
#  0.7074235807860262,
#  0.7030567685589519,
#  0.6943231441048034,
#  0.6855895196506551,
#  0.6899563318777293,
#  0.6986899563318777,
#  0.6899563318777293,
#  0.6855895196506551,
#  0.6943231441048034,
#  0.6899563318777293,
#  0.6812227074235808,
#  0.6768558951965066,
#  0.6855895196506551,
#  0.6943231441048034,
#  0.6899563318777293,
#  0.6899563318777293,
#  0.6899563318777293,
#  0.6899563318777293,
#  0.6899563318777293,
#  0.6855895196506551,
#  0.6899563318777293,
#  0.6855895196506551,
#  0.6899563318777293,
#  0.6812227074235808,
#  0.6812227074235808,
#  0.6943231441048034,
#  0.6899563318777293,
#  0.6943231441048034,
#  0.6943231441048034,
#  0.6855895196506551,
#  0.6943231441048034,
#  0.6943231441048034,
#  0.6899563318777293,
#  0.6899563318777293,
#  0.6899563318777293,
#  0.6855895196506551,
#  0.6812227074235808,
#  0.6768558951965066,
#  0.6724890829694323,
#  0.6681222707423581,
#  0.6593886462882096,
#  0.6593886462882096,
#  0.6724890829694323,
#  0.6550218340611353,
#  0.6550218340611353,
#  0.6550218340611353,
#  0.5895196506550219,
#  0.5807860262008734,
#  0.5633187772925764,
#  0.5895196506550219,
#  0.44541484716157204]

# %%
fig, ax = plt.subplots()
ax.set_xlabel("Alpha")
ax.set_ylabel("Accuracy")
ax.set_title("Accuracy vs alpha training and testing sets")
ax.plot(ccp_alpha, train_score, marker='o', label="train", drawstyle="steps-post")
ax.plot(ccp_alpha, test_score, marker='o', label="test",drawstyle="steps-post")
ax.legend()

# %%
dt_model_ccp=DecisionTreeClassifier(ccp_alpha=0.011,random_state=0)

# %%
dt_model_ccp.fit(X1,y1)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.011, random_state=0)

# %%
plt.figure(figsize=(20,20))
tree.plot_tree(dt_model_ccp,filled=True)
# Out:
# [Text(0.4230769230769231, 0.875, 'X[10] <= 9.75\ngini = 0.629\nsamples = 500\nvalue = [2, 16, 235, 186, 52, 9]'),
#  Text(0.15384615384615385, 0.625, 'X[9] <= 0.575\ngini = 0.471\nsamples = 228\nvalue = [2, 9, 155, 58, 4, 0]'),
#  Text(0.07692307692307693, 0.375, 'gini = 0.283\nsamples = 88\nvalue = [1, 5, 74, 7, 1, 0]'),
#  Text(0.23076923076923078, 0.375, 'X[6] <= 39.0\ngini = 0.531\nsamples = 140\nvalue = [1, 4, 81, 51, 3, 0]'),
#  Text(0.15384615384615385, 0.125, 'gini = 0.554\nsamples = 65\nvalue = [1, 1, 24, 36, 3, 0]'),
#  Text(0.3076923076923077, 0.125, 'gini = 0.381\nsamples = 75\nvalue = [0, 3, 57, 15, 0, 0]'),
#  Text(0.6923076923076923, 0.625, 'X[1] <= 0.555\ngini = 0.659\nsamples = 272\nvalue = [0, 7, 80, 128, 48, 9]'),
#  Text(0.5384615384615384, 0.375, 'X[2] <= 0.615\ngini = 0.619\nsamples = 163\nvalue = [0, 2, 28, 89, 37, 7]'),
#  Text(0.46153846153846156, 0.125, 'gini = 0.569\nsamples = 134\nvalue = [0, 2, 22, 82, 22, 6]'),
#  Text(0.6153846153846154, 0.125, 'gini = 0.63\nsamples = 29\nvalue = [0, 0, 6, 7, 15, 1]'),
#  Text(0.8461538461538461, 0.375, 'X[9] <= 0.595\ngini = 0.632\nsamples = 109\nvalue = [0, 5, 52, 39, 11, 2]'),
#  Text(0.7692307692307693, 0.125, 'gini = 0.504\nsamples = 56\nvalue = [0, 3, 37, 13, 3, 0]'),
#  Text(0.9230769230769231, 0.125, 'gini = 0.654\nsamples = 53\nvalue = [0, 2, 15, 26, 8, 2]')]

# %%
dt_model_ccp.score(X1,y1)
# Out:
# 0.654

# %%
dt_model_ccp.score(X_test,y_test)
# Out:
# 0.6550218340611353

# %%
DecisionTreeClassifier()
# Out:
# DecisionTreeClassifier()

# %%
grid_parm={
    "criterion":['gini','entropy'],
    "splitter":['best','random'],
    "max_depth":range(1,40,1),
    "min_samples_split":range(2,10,1),
    "min_samples_leaf":range(1,10,1)
#     "ccp_alpha":np.random.rand(20)
}

# %%
grid_ccp=GridSearchCV(estimator=dt_model_ccp, param_grid=grid_parm, cv=15, n_jobs=4)

# %%
grid_ccp.fit(X1,y1)
# Out:
# C:\Users\Aman\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:680: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=15.
#   warnings.warn(
# GridSearchCV(cv=15,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.011, random_state=0),
#              n_jobs=4,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 40),
#                          'min_samples_leaf': range(1, 10),
#                          'min_samples_split': range(2, 10),
#                          'splitter': ['best', 'random']})

# %%
grid_ccp.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 7,
#  'min_samples_leaf': 7,
#  'min_samples_split': 2,
#  'splitter': 'random'}

# %%
dt_model_cpp_new=DecisionTreeClassifier(ccp_alpha=0.01103,criterion="entropy", max_depth=7, min_samples_leaf=7, min_samples_split=2, splitter='random')

# %%
dt_model_cpp_new.fit(X1,y1)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.01103, criterion='entropy', max_depth=7,
#                        min_samples_leaf=7, splitter='random')

# %%
dt_model_cpp_new.score(X1,y1)
# Out:
# 0.666

# %%
dt_model_cpp_new.score(X_test,y_test)
# Out:
# 0.6637554585152838

# %%
pread=dt_model_cpp_new.predict(X_train)

# %%
confusion_matrix(y_train,pread)
# Out:
# array([[  0,   0,   4,   2,   0,   0],
#        [  0,   0,  16,   9,   0,   0],
#        [  0,   0, 248, 119,  14,   0],
#        [  0,   0,  79, 250,  36,   0],
#        [  0,   0,  10,  62,  49,   0],
#        [  0,   0,   0,  14,   2,   0]], dtype=int64)

# %% [markdown]
# #### Why are we getting 0 in confusion metrices??
# Ans: At the time of training we used X1 and y1 in that some class was not availabe so it is giving zeros

# %%
X=df.drop(columns=["quality"])

# %%
y=df.quality

# %%
from sklearn.ensemble import BaggingClassifier

# %%
# By default test_size=0.25
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0)

# %%
bag_dt=BaggingClassifier(DecisionTreeClassifier(),n_estimators=100) 
# n_estimator is number of models in a bag in this case it is 10 DT

# %%
bag_dt.fit(X_train,y_train)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=100)

# %%
bag_dt.predict(X_test)
# Out:
# array([5, 5, 5, 6, 5, 6, 6, 6, 6, 6, 5, 5, 5, 6, 6, 5, 6, 6, 5, 5, 6, 5,
#        5, 6, 5, 6, 6, 6, 5, 6, 5, 5, 6, 6, 5, 6, 6, 6, 5, 6, 5, 6, 5, 6,
#        5, 5, 5, 6, 6, 6, 5, 5, 5, 7, 5, 5, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5,
#        7, 5, 6, 7, 5, 5, 6, 7, 6, 7, 7, 6, 6, 6, 5, 6, 6, 5, 6, 6, 5, 5,
#        5, 6, 6, 7, 5, 5, 5, 5, 5, 5, 5, 5, 5, 6, 7, 5, 5, 6, 6, 6, 5, 5,
#        5, 5, 5, 7, 5, 5, 4, 5, 6, 7, 6, 5, 6, 6, 7, 6, 6, 6, 5, 5, 7, 6,
#        5, 5, 5, 6, 5, 7, 6, 5, 6, 5, 6, 7, 5, 5, 6, 6, 7, 5, 5, 6, 6, 6,
#        5, 6, 5, 7, 6, 6, 6, 6, 5, 5, 5, 6, 6, 7, 5, 6, 5, 5, 5, 6, 6, 5,
#        6, 6, 5, 6, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 7, 5, 5, 6, 6, 5, 5, 6,
#        6, 5, 6, 6, 6, 7, 7, 6, 5, 5, 6, 5, 6, 6, 5, 6, 5, 5, 6, 6, 5, 6,
#        6, 6, 6, 6, 6, 6, 7, 5, 5, 5, 6, 7, 5, 6, 6, 6, 8, 5, 5, 6, 7, 6,
#        6, 6, 6, 5, 6, 5, 7, 5, 5, 6, 5, 5, 6, 6, 5, 6, 6, 5, 5, 6, 6, 6,
#        5, 5, 6, 6, 6, 6, 5, 5, 5, 5, 6, 5, 6, 6, 7, 5, 7, 5, 5, 6, 7, 5],
#       dtype=int64)

# %%
bag_dt.base_estimator
# Out:
# DecisionTreeClassifier()

# %%
bag_dt.estimator_params
# Out:
# ()

# %%
bag_dt.classes_
# Out:
# array([3, 4, 5, 6, 7, 8], dtype=int64)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
bag_knn=BaggingClassifier(KNeighborsClassifier(6), n_estimators=10)

# %%
bag_knn.fit(X_train,y_train)
# Out:
# BaggingClassifier(base_estimator=KNeighborsClassifier(n_neighbors=6))

# %%
bag_knn.predict(X_test)
# Out:
# array([6, 6, 5, 7, 5, 7, 5, 6, 5, 6, 5, 6, 5, 6, 6, 6, 7, 6, 6, 5, 6, 6,
#        5, 5, 5, 7, 6, 6, 6, 5, 5, 5, 6, 5, 5, 6, 6, 5, 5, 6, 6, 6, 5, 6,
#        5, 5, 6, 6, 6, 6, 6, 5, 5, 7, 5, 6, 6, 5, 5, 6, 7, 5, 5, 6, 5, 6,
#        6, 5, 5, 6, 5, 6, 6, 6, 5, 6, 7, 6, 6, 6, 5, 5, 5, 6, 6, 5, 5, 6,
#        6, 6, 6, 7, 6, 5, 5, 5, 6, 5, 5, 5, 6, 6, 6, 5, 6, 5, 5, 5, 6, 6,
#        6, 5, 5, 6, 6, 3, 5, 6, 5, 7, 6, 6, 7, 6, 6, 7, 6, 6, 5, 6, 7, 6,
#        5, 5, 5, 6, 5, 6, 6, 6, 5, 6, 6, 5, 5, 6, 5, 6, 6, 5, 5, 7, 7, 5,
#        5, 5, 5, 6, 5, 6, 5, 7, 6, 5, 6, 6, 6, 5, 6, 5, 6, 6, 5, 5, 6, 6,
#        6, 5, 6, 6, 5, 5, 5, 5, 5, 5, 6, 5, 5, 6, 5, 5, 6, 6, 6, 6, 5, 5,
#        5, 6, 6, 7, 6, 7, 6, 6, 5, 5, 6, 7, 5, 6, 6, 5, 5, 5, 6, 6, 5, 6,
#        6, 6, 5, 5, 5, 5, 7, 5, 5, 7, 6, 6, 6, 5, 6, 5, 7, 5, 6, 6, 7, 7,
#        6, 5, 6, 5, 5, 6, 6, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 5, 5, 6, 5, 7,
#        5, 5, 6, 6, 6, 5, 6, 5, 5, 5, 6, 6, 6, 5, 7, 5, 5, 6, 6, 6, 6, 6],
#       dtype=int64)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=5,verbose=1)

# %%
rf.fit(X_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s finished
# RandomForestClassifier(n_estimators=5, verbose=1)

# %%
rf.score(X_test,y_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s finished
# 0.6678321678321678

# %%
bag_dt.score(X_test,y_test)
# Out:
# 0.6503496503496503

# %%
bag_knn.score(X_test,y_test)
# Out:
# 0.48951048951048953

# %%
# It will give you number of trees created
rf.estimators_
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=1320298544),
#  DecisionTreeClassifier(max_features='sqrt', random_state=687132777),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1193837279),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2021090909),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1968823519)]

# %%
rf.estimators_[0]
# Out:
# DecisionTreeClassifier(max_features='sqrt', random_state=1320298544)

# %%
plt.figure(figsize=(20,20))
tree.plot_tree(rf.estimators_[0],filled=True)
# Out:
# [Text(0.37744250846501126, 0.9666666666666667, 'X[10] <= 9.75\ngini = 0.653\nsamples = 529\nvalue = [6, 33, 337, 360, 102, 19]'),
#  Text(0.1544864559819413, 0.9, 'X[5] <= 15.5\ngini = 0.46\nsamples = 167\nvalue = [2, 18, 184, 61, 0, 0]'),
#  Text(0.11371331828442438, 0.8333333333333334, 'X[11] <= 998.0\ngini = 0.54\nsamples = 94\nvalue = [2, 11, 88, 47, 0, 0]'),
#  Text(0.07618510158013544, 0.7666666666666667, 'X[3] <= 1.95\ngini = 0.492\nsamples = 85\nvalue = [2, 5, 85, 40, 0, 0]'),
#  Text(0.045146726862302484, 0.7, 'X[2] <= 0.58\ngini = 0.335\nsamples = 37\nvalue = [0, 1, 46, 11, 0, 0]'),
#  Text(0.040632054176072234, 0.6333333333333333, 'X[1] <= 0.553\ngini = 0.318\nsamples = 36\nvalue = [0, 1, 46, 10, 0, 0]'),
#  Text(0.022573363431151242, 0.5666666666666667, 'X[9] <= 0.645\ngini = 0.463\nsamples = 14\nvalue = [0, 0, 14, 8, 0, 0]'),
#  Text(0.013544018058690745, 0.5, 'X[10] <= 9.25\ngini = 0.231\nsamples = 9\nvalue = [0, 0, 13, 2, 0, 0]'),
#  Text(0.009029345372460496, 0.43333333333333335, 'X[1] <= 0.425\ngini = 0.48\nsamples = 4\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.004514672686230248, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.013544018058690745, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.01805869074492099, 0.43333333333333335, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.03160270880361174, 0.5, 'X[2] <= 0.385\ngini = 0.245\nsamples = 5\nvalue = [0, 0, 1, 6, 0, 0]'),
#  Text(0.02708803611738149, 0.43333333333333335, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.03611738148984198, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.05869074492099323, 0.5666666666666667, 'X[4] <= 0.062\ngini = 0.16\nsamples = 22\nvalue = [0, 1, 32, 2, 0, 0]'),
#  Text(0.04966139954853273, 0.5, 'X[0] <= 7.35\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.045146726862302484, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.05417607223476298, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.06772009029345373, 0.5, 'X[0] <= 7.3\ngini = 0.114\nsamples = 20\nvalue = [0, 0, 31, 2, 0, 0]'),
#  Text(0.06320541760722348, 0.43333333333333335, 'X[4] <= 0.08\ngini = 0.231\nsamples = 9\nvalue = [0, 0, 13, 2, 0, 0]'),
#  Text(0.05869074492099323, 0.36666666666666664, 'X[5] <= 7.5\ngini = 0.444\nsamples = 5\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(0.05417607223476298, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.06320541760722348, 0.3, 'X[6] <= 25.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.05869074492099323, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.06772009029345373, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.06772009029345373, 0.36666666666666664, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.07223476297968397, 0.43333333333333335, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 18, 0, 0, 0]'),
#  Text(0.04966139954853273, 0.6333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1072234762979684, 0.7, 'X[3] <= 2.15\ngini = 0.565\nsamples = 48\nvalue = [2, 4, 39, 29, 0, 0]'),
#  Text(0.09029345372460497, 0.6333333333333333, 'X[9] <= 0.525\ngini = 0.579\nsamples = 20\nvalue = [1, 4, 8, 18, 0, 0]'),
#  Text(0.08577878103837472, 0.5666666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.09480812641083522, 0.5666666666666667, 'X[1] <= 0.662\ngini = 0.51\nsamples = 17\nvalue = [1, 4, 4, 18, 0, 0]'),
#  Text(0.08577878103837472, 0.5, 'X[4] <= 0.195\ngini = 0.185\nsamples = 13\nvalue = [1, 0, 1, 18, 0, 0]'),
#  Text(0.08126410835214447, 0.43333333333333335, 'X[8] <= 3.355\ngini = 0.1\nsamples = 12\nvalue = [0, 0, 1, 18, 0, 0]'),
#  Text(0.07674943566591422, 0.36666666666666664, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 15, 0, 0]'),
#  Text(0.08577878103837472, 0.36666666666666664, 'X[7] <= 0.997\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.08126410835214447, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.09029345372460497, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.09029345372460497, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.1038374717832957, 0.5, 'X[6] <= 79.5\ngini = 0.49\nsamples = 4\nvalue = [0, 4, 3, 0, 0, 0]'),
#  Text(0.09932279909706546, 0.43333333333333335, 'X[2] <= 0.02\ngini = 0.32\nsamples = 3\nvalue = [0, 4, 1, 0, 0, 0]'),
#  Text(0.09480812641083522, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.1038374717832957, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 4, 0, 0, 0, 0]'),
#  Text(0.10835214446952596, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.12415349887133183, 0.6333333333333333, 'X[1] <= 0.275\ngini = 0.414\nsamples = 28\nvalue = [1, 0, 31, 11, 0, 0]'),
#  Text(0.11963882618510158, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.12866817155756208, 0.5666666666666667, 'X[7] <= 0.996\ngini = 0.359\nsamples = 26\nvalue = [1, 0, 31, 8, 0, 0]'),
#  Text(0.12415349887133183, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.13318284424379231, 0.5, 'X[1] <= 0.78\ngini = 0.309\nsamples = 25\nvalue = [1, 0, 31, 6, 0, 0]'),
#  Text(0.12189616252821671, 0.43333333333333335, 'X[10] <= 9.25\ngini = 0.251\nsamples = 23\nvalue = [1, 0, 30, 4, 0, 0]'),
#  Text(0.11286681715575621, 0.36666666666666664, 'X[5] <= 12.0\ngini = 0.594\nsamples = 6\nvalue = [1, 0, 4, 3, 0, 0]'),
#  Text(0.10835214446952596, 0.3, 'X[6] <= 45.0\ngini = 0.32\nsamples = 4\nvalue = [1, 0, 4, 0, 0, 0]'),
#  Text(0.1038374717832957, 0.23333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.11286681715575621, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.11738148984198646, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.1309255079006772, 0.36666666666666664, 'X[6] <= 13.5\ngini = 0.071\nsamples = 17\nvalue = [0, 0, 26, 1, 0, 0]'),
#  Text(0.12641083521444696, 0.3, 'X[2] <= 0.56\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.12189616252821671, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1309255079006772, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.13544018058690746, 0.3, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 25, 0, 0, 0]'),
#  Text(0.14446952595936793, 0.43333333333333335, 'X[11] <= 264.5\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.1399548532731377, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.1489841986455982, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.15124153498871332, 0.7666666666666667, 'X[2] <= 0.075\ngini = 0.633\nsamples = 9\nvalue = [0, 6, 3, 7, 0, 0]'),
#  Text(0.14672686230248308, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 6, 0, 0, 0, 0]'),
#  Text(0.15575620767494355, 0.7, 'X[5] <= 11.5\ngini = 0.42\nsamples = 7\nvalue = [0, 0, 3, 7, 0, 0]'),
#  Text(0.15124153498871332, 0.6333333333333333, 'X[2] <= 0.105\ngini = 0.5\nsamples = 5\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(0.14672686230248308, 0.5666666666666667, 'X[6] <= 11.5\ngini = 0.375\nsamples = 3\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.14221218961625282, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.15124153498871332, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.15575620767494355, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.16027088036117382, 0.6333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.19525959367945825, 0.8333333333333334, 'X[3] <= 1.55\ngini = 0.309\nsamples = 73\nvalue = [0, 7, 96, 14, 0, 0]'),
#  Text(0.19074492099322798, 0.7666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.19977426636568849, 0.7666666666666667, 'X[1] <= 0.385\ngini = 0.286\nsamples = 72\nvalue = [0, 5, 96, 14, 0, 0]'),
#  Text(0.17832957110609482, 0.7, 'X[2] <= 0.445\ngini = 0.625\nsamples = 7\nvalue = [0, 2, 5, 5, 0, 0]'),
#  Text(0.16930022573363432, 0.6333333333333333, 'X[3] <= 2.9\ngini = 0.278\nsamples = 4\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(0.16478555304740405, 0.5666666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.17381489841986456, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.1873589164785553, 0.6333333333333333, 'X[11] <= 691.0\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 4, 0, 0, 0]'),
#  Text(0.18284424379232506, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.19187358916478556, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.22121896162528218, 0.7, 'X[6] <= 99.5\ngini = 0.211\nsamples = 65\nvalue = [0, 3, 91, 9, 0, 0]'),
#  Text(0.21670428893905191, 0.6333333333333333, 'X[3] <= 3.95\ngini = 0.322\nsamples = 42\nvalue = [0, 3, 51, 9, 0, 0]'),
#  Text(0.20090293453724606, 0.5666666666666667, 'X[1] <= 0.435\ngini = 0.251\nsamples = 37\nvalue = [0, 3, 49, 5, 0, 0]'),
#  Text(0.19187358916478556, 0.5, 'X[10] <= 9.45\ngini = 0.397\nsamples = 8\nvalue = [0, 0, 8, 3, 0, 0]'),
#  Text(0.1873589164785553, 0.43333333333333335, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.1963882618510158, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.20993227990970656, 0.5, 'X[11] <= 61.5\ngini = 0.199\nsamples = 29\nvalue = [0, 3, 41, 2, 0, 0]'),
#  Text(0.2054176072234763, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.2144469525959368, 0.43333333333333335, 'X[9] <= 0.78\ngini = 0.129\nsamples = 28\nvalue = [0, 1, 41, 2, 0, 0]'),
#  Text(0.20316027088036118, 0.36666666666666664, 'X[6] <= 90.5\ngini = 0.094\nsamples = 26\nvalue = [0, 1, 39, 1, 0, 0]'),
#  Text(0.19413092550790068, 0.3, 'X[10] <= 9.05\ngini = 0.051\nsamples = 24\nvalue = [0, 1, 37, 0, 0, 0]'),
#  Text(0.18961625282167044, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.1986455981941309, 0.23333333333333334, 'gini = 0.0\nsamples = 23\nvalue = [0, 0, 37, 0, 0, 0]'),
#  Text(0.21218961625282168, 0.3, 'X[1] <= 0.51\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.2076749435665914, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.21670428893905191, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.22573363431151242, 0.36666666666666664, 'X[6] <= 50.5\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.22121896162528218, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.23024830699774265, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2325056433408578, 0.5666666666666667, 'X[9] <= 0.65\ngini = 0.444\nsamples = 5\nvalue = [0, 0, 2, 4, 0, 0]'),
#  Text(0.22799097065462753, 0.5, 'X[3] <= 5.3\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.2234762979683973, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2325056433408578, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.23702031602708803, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.22573363431151242, 0.6333333333333333, 'gini = 0.0\nsamples = 23\nvalue = [0, 0, 40, 0, 0, 0]'),
#  Text(0.6003985609480813, 0.9, 'X[10] <= 10.75\ngini = 0.647\nsamples = 362\nvalue = [4, 15, 153, 299, 102, 19]'),
#  Text(0.44723476297968395, 0.8333333333333334, 'X[1] <= 0.605\ngini = 0.585\nsamples = 169\nvalue = [4, 5, 106, 150, 20, 2]'),
#  Text(0.39418735891647855, 0.7666666666666667, 'X[4] <= 0.09\ngini = 0.541\nsamples = 111\nvalue = [0, 2, 54, 120, 18, 2]'),
#  Text(0.3594808126410835, 0.7, 'X[2] <= 0.58\ngini = 0.477\nsamples = 81\nvalue = [0, 0, 32, 94, 10, 2]'),
#  Text(0.3306997742663657, 0.6333333333333333, 'X[11] <= 1390.5\ngini = 0.442\nsamples = 76\nvalue = [0, 0, 26, 93, 10, 1]'),
#  Text(0.3002257336343115, 0.5666666666666667, 'X[0] <= 6.4\ngini = 0.339\nsamples = 63\nvalue = [0, 0, 16, 91, 7, 0]'),
#  Text(0.29571106094808125, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3047404063205418, 0.5, 'X[8] <= 3.425\ngini = 0.32\nsamples = 62\nvalue = [0, 0, 14, 91, 7, 0]'),
#  Text(0.2799097065462754, 0.43333333333333335, 'X[9] <= 0.645\ngini = 0.265\nsamples = 52\nvalue = [0, 0, 7, 80, 7, 0]'),
#  Text(0.25733634311512416, 0.36666666666666664, 'X[8] <= 3.255\ngini = 0.213\nsamples = 36\nvalue = [0, 0, 7, 59, 1, 0]'),
#  Text(0.23927765237020315, 0.3, 'X[6] <= 23.5\ngini = 0.444\nsamples = 12\nvalue = [0, 0, 6, 12, 0, 0]'),
#  Text(0.23476297968397292, 0.23333333333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.24379232505643342, 0.23333333333333334, 'X[1] <= 0.26\ngini = 0.496\nsamples = 7\nvalue = [0, 0, 6, 5, 0, 0]'),
#  Text(0.23927765237020315, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.24830699774266365, 0.16666666666666666, 'X[11] <= 657.5\ngini = 0.469\nsamples = 6\nvalue = [0, 0, 3, 5, 0, 0]'),
#  Text(0.24379232505643342, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.2528216704288939, 0.1, 'X[6] <= 36.5\ngini = 0.375\nsamples = 3\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.24830699774266365, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.25733634311512416, 0.03333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.27539503386004516, 0.3, 'X[4] <= 0.087\ngini = 0.079\nsamples = 24\nvalue = [0, 0, 1, 47, 1, 0]'),
#  Text(0.2708803611738149, 0.23333333333333334, 'X[0] <= 7.15\ngini = 0.041\nsamples = 23\nvalue = [0, 0, 1, 47, 0, 0]'),
#  Text(0.26636568848758463, 0.16666666666666666, 'X[7] <= 0.996\ngini = 0.111\nsamples = 8\nvalue = [0, 0, 1, 16, 0, 0]'),
#  Text(0.2618510158013544, 0.1, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.2708803611738149, 0.1, 'X[1] <= 0.435\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.26636568848758463, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.27539503386004516, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.27539503386004516, 0.16666666666666666, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 0, 31, 0, 0]'),
#  Text(0.2799097065462754, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.30248306997742663, 0.36666666666666664, 'X[7] <= 0.997\ngini = 0.346\nsamples = 16\nvalue = [0, 0, 0, 21, 6, 0]'),
#  Text(0.29345372460496616, 0.3, 'X[7] <= 0.997\ngini = 0.5\nsamples = 5\nvalue = [0, 0, 0, 4, 4, 0]'),
#  Text(0.28893905191873587, 0.23333333333333334, 'X[7] <= 0.996\ngini = 0.32\nsamples = 3\nvalue = [0, 0, 0, 4, 1, 0]'),
#  Text(0.28442437923250563, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.29345372460496616, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.2979683972911964, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.3115124153498871, 0.3, 'X[9] <= 0.775\ngini = 0.188\nsamples = 11\nvalue = [0, 0, 0, 17, 2, 0]'),
#  Text(0.30699774266365687, 0.23333333333333334, 'X[0] <= 9.1\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.30248306997742663, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.3115124153498871, 0.16666666666666666, 'X[3] <= 2.25\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.30699774266365687, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.3160270880361174, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3160270880361174, 0.23333333333333334, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 16, 0, 0]'),
#  Text(0.3295711060948081, 0.43333333333333335, 'X[9] <= 0.625\ngini = 0.475\nsamples = 10\nvalue = [0, 0, 7, 11, 0, 0]'),
#  Text(0.32505643340857787, 0.36666666666666664, 'X[10] <= 10.45\ngini = 0.219\nsamples = 6\nvalue = [0, 0, 7, 1, 0, 0]'),
#  Text(0.32054176072234764, 0.3, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.3295711060948081, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3340857787810384, 0.36666666666666664, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.3611738148984199, 0.5666666666666667, 'X[8] <= 3.315\ngini = 0.555\nsamples = 13\nvalue = [0, 0, 10, 2, 3, 1]'),
#  Text(0.35214446952595935, 0.5, 'X[8] <= 3.28\ngini = 0.719\nsamples = 7\nvalue = [0, 0, 3, 2, 2, 1]'),
#  Text(0.3476297968397291, 0.43333333333333335, 'X[6] <= 16.0\ngini = 0.611\nsamples = 6\nvalue = [0, 0, 3, 2, 0, 1]'),
#  Text(0.3431151241534989, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.35214446952595935, 0.36666666666666664, 'X[0] <= 7.7\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.3476297968397291, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.35665914221218964, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.35665914221218964, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.37020316027088035, 0.5, 'X[9] <= 0.66\ngini = 0.219\nsamples = 6\nvalue = [0, 0, 7, 0, 1, 0]'),
#  Text(0.3656884875846501, 0.43333333333333335, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.3747178329571106, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.38826185101580135, 0.6333333333333333, 'X[2] <= 0.69\ngini = 0.406\nsamples = 5\nvalue = [0, 0, 6, 1, 0, 1]'),
#  Text(0.3837471783295711, 0.5666666666666667, 'X[0] <= 12.55\ngini = 0.245\nsamples = 4\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(0.3792325056433409, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.38826185101580135, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3927765237020316, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.4288939051918736, 0.7, 'X[10] <= 10.35\ngini = 0.635\nsamples = 30\nvalue = [0, 2, 22, 26, 8, 0]'),
#  Text(0.4108352144469526, 0.6333333333333333, 'X[11] <= 569.5\ngini = 0.544\nsamples = 17\nvalue = [0, 2, 4, 21, 6, 0]'),
#  Text(0.4018058690744921, 0.5666666666666667, 'X[9] <= 0.55\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 2, 20, 0, 0]'),
#  Text(0.3972911963882618, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.40632054176072235, 0.5, 'X[11] <= 437.5\ngini = 0.091\nsamples = 10\nvalue = [0, 0, 1, 20, 0, 0]'),
#  Text(0.4018058690744921, 0.43333333333333335, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.4108352144469526, 0.43333333333333335, 'X[5] <= 12.5\ngini = 0.245\nsamples = 3\nvalue = [0, 0, 1, 6, 0, 0]'),
#  Text(0.40632054176072235, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4153498871331828, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.4198645598194131, 0.5666666666666667, 'X[9] <= 0.58\ngini = 0.628\nsamples = 6\nvalue = [0, 2, 2, 1, 6, 0]'),
#  Text(0.4153498871331828, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.42437923250564336, 0.5, 'X[6] <= 55.5\ngini = 0.494\nsamples = 5\nvalue = [0, 0, 2, 1, 6, 0]'),
#  Text(0.4198645598194131, 0.43333333333333335, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.4288939051918736, 0.43333333333333335, 'X[1] <= 0.36\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.42437923250564336, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.43340857787810383, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.4469525959367946, 0.6333333333333333, 'X[9] <= 0.715\ngini = 0.435\nsamples = 13\nvalue = [0, 0, 18, 5, 2, 0]'),
#  Text(0.43792325056433407, 0.5666666666666667, 'X[3] <= 3.2\ngini = 0.1\nsamples = 9\nvalue = [0, 0, 18, 1, 0, 0]'),
#  Text(0.43340857787810383, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 18, 0, 0, 0]'),
#  Text(0.44243792325056436, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.45598194130925507, 0.5666666666666667, 'X[11] <= 388.0\ngini = 0.444\nsamples = 4\nvalue = [0, 0, 0, 4, 2, 0]'),
#  Text(0.45146726862302483, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.4604966139954853, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.5002821670428894, 0.7666666666666667, 'X[4] <= 0.065\ngini = 0.561\nsamples = 58\nvalue = [4, 3, 52, 30, 2, 0]'),
#  Text(0.4762979683972912, 0.7, 'X[2] <= 0.035\ngini = 0.494\nsamples = 6\nvalue = [0, 2, 0, 6, 1, 0]'),
#  Text(0.4717832957110609, 0.6333333333333333, 'X[7] <= 0.996\ngini = 0.444\nsamples = 2\nvalue = [0, 2, 0, 0, 1, 0]'),
#  Text(0.4672686230248307, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.4762979683972912, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.48081264108352145, 0.6333333333333333, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.5242663656884876, 0.7, 'X[2] <= 0.31\ngini = 0.51\nsamples = 52\nvalue = [4, 1, 52, 24, 1, 0]'),
#  Text(0.5067720090293454, 0.6333333333333333, 'X[0] <= 7.55\ngini = 0.474\nsamples = 49\nvalue = [4, 1, 52, 20, 0, 0]'),
#  Text(0.4853273137697517, 0.5666666666666667, 'X[11] <= 1391.5\ngini = 0.32\nsamples = 25\nvalue = [4, 1, 31, 2, 0, 0]'),
#  Text(0.46952595936794583, 0.5, 'X[7] <= 0.995\ngini = 0.142\nsamples = 18\nvalue = [0, 0, 24, 2, 0, 0]'),
#  Text(0.4604966139954853, 0.43333333333333335, 'X[5] <= 14.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.45598194130925507, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4650112866817156, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4785553047404063, 0.43333333333333335, 'X[9] <= 0.845\ngini = 0.08\nsamples = 16\nvalue = [0, 0, 23, 1, 0, 0]'),
#  Text(0.47404063205417607, 0.36666666666666664, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 23, 0, 0, 0]'),
#  Text(0.48306997742663654, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5011286681715575, 0.5, 'X[5] <= 9.0\ngini = 0.542\nsamples = 7\nvalue = [4, 1, 7, 0, 0, 0]'),
#  Text(0.4966139954853273, 0.43333333333333335, 'X[8] <= 3.605\ngini = 0.32\nsamples = 3\nvalue = [4, 1, 0, 0, 0, 0]'),
#  Text(0.49209932279909707, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [4, 0, 0, 0, 0, 0]'),
#  Text(0.5011286681715575, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5056433408577878, 0.43333333333333335, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.5282167042889391, 0.5666666666666667, 'X[10] <= 10.3\ngini = 0.497\nsamples = 24\nvalue = [0, 0, 21, 18, 0, 0]'),
#  Text(0.5237020316027088, 0.5, 'X[6] <= 18.0\ngini = 0.346\nsamples = 18\nvalue = [0, 0, 21, 6, 0, 0]'),
#  Text(0.5146726862302483, 0.43333333333333335, 'X[7] <= 0.997\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.510158013544018, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5191873589164786, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5327313769751693, 0.43333333333333335, 'X[11] <= 258.0\ngini = 0.278\nsamples = 16\nvalue = [0, 0, 20, 4, 0, 0]'),
#  Text(0.5282167042889391, 0.36666666666666664, 'X[0] <= 8.15\ngini = 0.32\nsamples = 4\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.5237020316027088, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.5327313769751693, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5372460496613995, 0.36666666666666664, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 19, 0, 0, 0]'),
#  Text(0.5327313769751693, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.5417607223476298, 0.6333333333333333, 'X[11] <= 397.5\ngini = 0.32\nsamples = 3\nvalue = [0, 0, 0, 4, 1, 0]'),
#  Text(0.5372460496613995, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.54627539503386, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.7535623589164786, 0.8333333333333334, 'X[10] <= 11.65\ngini = 0.661\nsamples = 193\nvalue = [0, 10, 47, 149, 82, 17]'),
#  Text(0.6435524830699775, 0.7666666666666667, 'X[5] <= 5.5\ngini = 0.647\nsamples = 112\nvalue = [0, 9, 35, 96, 35, 8]'),
#  Text(0.5733634311512416, 0.7, 'X[1] <= 0.36\ngini = 0.774\nsamples = 20\nvalue = [0, 5, 10, 12, 7, 5]'),
#  Text(0.5598194130925508, 0.6333333333333333, 'X[4] <= 0.067\ngini = 0.631\nsamples = 6\nvalue = [0, 0, 0, 3, 7, 5]'),
#  Text(0.5553047404063205, 0.5666666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.5643340857787811, 0.5666666666666667, 'X[0] <= 9.9\ngini = 0.469\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 5]'),
#  Text(0.5598194130925508, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.5688487584650113, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 5]'),
#  Text(0.5869074492099323, 0.6333333333333333, 'X[7] <= 0.998\ngini = 0.642\nsamples = 14\nvalue = [0, 5, 10, 9, 0, 0]'),
#  Text(0.582392776523702, 0.5666666666666667, 'X[6] <= 13.5\ngini = 0.602\nsamples = 10\nvalue = [0, 5, 3, 9, 0, 0]'),
#  Text(0.5778781038374717, 0.5, 'X[1] <= 0.465\ngini = 0.469\nsamples = 5\nvalue = [0, 5, 3, 0, 0, 0]'),
#  Text(0.5733634311512416, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.582392776523702, 0.43333333333333335, 'X[3] <= 2.3\ngini = 0.48\nsamples = 4\nvalue = [0, 2, 3, 0, 0, 0]'),
#  Text(0.5778781038374717, 0.36666666666666664, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.5869074492099323, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.5869074492099323, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.5914221218961625, 0.5666666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.7137415349887133, 0.7, 'X[6] <= 34.5\ngini = 0.591\nsamples = 92\nvalue = [0, 4, 25, 84, 28, 3]'),
#  Text(0.6645033860045146, 0.6333333333333333, 'X[11] <= 981.5\ngini = 0.632\nsamples = 49\nvalue = [0, 2, 9, 39, 25, 3]'),
#  Text(0.6331828442437923, 0.5666666666666667, 'X[7] <= 0.998\ngini = 0.59\nsamples = 18\nvalue = [0, 0, 5, 8, 16, 0]'),
#  Text(0.6162528216704289, 0.5, 'X[7] <= 0.996\ngini = 0.475\nsamples = 14\nvalue = [0, 0, 5, 2, 15, 0]'),
#  Text(0.6049661399548533, 0.43333333333333335, 'X[7] <= 0.994\ngini = 0.625\nsamples = 6\nvalue = [0, 0, 4, 2, 2, 0]'),
#  Text(0.5959367945823928, 0.36666666666666664, 'X[9] <= 0.63\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.5914221218961625, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.600451467268623, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6139954853273137, 0.36666666666666664, 'X[2] <= 0.09\ngini = 0.32\nsamples = 4\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.6094808126410836, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.618510158013544, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.6275395033860045, 0.43333333333333335, 'X[11] <= 475.5\ngini = 0.133\nsamples = 8\nvalue = [0, 0, 1, 0, 13, 0]'),
#  Text(0.6230248306997742, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6320541760722348, 0.36666666666666664, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 13, 0]'),
#  Text(0.6501128668171557, 0.5, 'X[11] <= 401.5\ngini = 0.245\nsamples = 4\nvalue = [0, 0, 0, 6, 1, 0]'),
#  Text(0.6455981941309256, 0.43333333333333335, 'X[2] <= 0.61\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.6410835214446953, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.6501128668171557, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.654627539503386, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.695823927765237, 0.5666666666666667, 'X[5] <= 16.5\ngini = 0.554\nsamples = 31\nvalue = [0, 2, 4, 31, 9, 3]'),
#  Text(0.6805869074492099, 0.5, 'X[9] <= 0.665\ngini = 0.491\nsamples = 29\nvalue = [0, 2, 4, 31, 7, 1]'),
#  Text(0.6636568848758465, 0.43333333333333335, 'X[11] <= 1290.0\ngini = 0.227\nsamples = 13\nvalue = [0, 0, 3, 20, 0, 0]'),
#  Text(0.6591422121896162, 0.36666666666666664, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 16, 0, 0]'),
#  Text(0.6681715575620768, 0.36666666666666664, 'X[5] <= 12.0\ngini = 0.49\nsamples = 5\nvalue = [0, 0, 3, 4, 0, 0]'),
#  Text(0.6636568848758465, 0.3, 'X[5] <= 7.0\ngini = 0.375\nsamples = 3\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.6591422121896162, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6681715575620768, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.672686230248307, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.6975169300225733, 0.43333333333333335, 'X[11] <= 1134.5\ngini = 0.636\nsamples = 16\nvalue = [0, 2, 1, 11, 7, 1]'),
#  Text(0.6930022573363431, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.7020316027088036, 0.36666666666666664, 'X[7] <= 0.996\ngini = 0.62\nsamples = 14\nvalue = [0, 2, 1, 11, 5, 1]'),
#  Text(0.6862302483069977, 0.3, 'X[2] <= 0.315\ngini = 0.612\nsamples = 6\nvalue = [0, 0, 1, 1, 4, 1]'),
#  Text(0.6772009029345373, 0.23333333333333334, 'X[8] <= 3.325\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.672686230248307, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.6817155756207675, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6952595936794582, 0.23333333333333334, 'X[5] <= 9.5\ngini = 0.32\nsamples = 4\nvalue = [0, 0, 1, 0, 4, 0]'),
#  Text(0.690744920993228, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6997742663656885, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.7178329571106095, 0.3, 'X[8] <= 3.415\ngini = 0.379\nsamples = 8\nvalue = [0, 2, 0, 10, 1, 0]'),
#  Text(0.7133182844243793, 0.23333333333333334, 'X[0] <= 7.85\ngini = 0.165\nsamples = 7\nvalue = [0, 0, 0, 10, 1, 0]'),
#  Text(0.708803611738149, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7178329571106095, 0.16666666666666666, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.7223476297968398, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.7110609480812641, 0.5, 'X[4] <= 0.068\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 2]'),
#  Text(0.7065462753950339, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.7155756207674944, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.7629796839729119, 0.6333333333333333, 'X[10] <= 11.15\ngini = 0.473\nsamples = 43\nvalue = [0, 2, 16, 45, 3, 0]'),
#  Text(0.7426636568848759, 0.5666666666666667, 'X[6] <= 50.5\ngini = 0.513\nsamples = 25\nvalue = [0, 0, 16, 22, 1, 0]'),
#  Text(0.7291196388261851, 0.5, 'X[9] <= 0.585\ngini = 0.431\nsamples = 14\nvalue = [0, 0, 5, 15, 1, 0]'),
#  Text(0.7246049661399548, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.7336343115124153, 0.43333333333333335, 'X[8] <= 3.395\ngini = 0.215\nsamples = 12\nvalue = [0, 0, 1, 15, 1, 0]'),
#  Text(0.7291196388261851, 0.36666666666666664, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 13, 0, 0]'),
#  Text(0.7381489841986456, 0.36666666666666664, 'X[6] <= 36.0\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 2, 1, 0]'),
#  Text(0.7336343115124153, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7426636568848759, 0.3, 'X[1] <= 0.48\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.7381489841986456, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7471783295711061, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7562076749435666, 0.5, 'X[4] <= 0.103\ngini = 0.475\nsamples = 11\nvalue = [0, 0, 11, 7, 0, 0]'),
#  Text(0.7516930022573364, 0.43333333333333335, 'X[11] <= 1105.0\ngini = 0.43\nsamples = 9\nvalue = [0, 0, 11, 5, 0, 0]'),
#  Text(0.7471783295711061, 0.36666666666666664, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.7562076749435666, 0.36666666666666664, 'X[1] <= 0.51\ngini = 0.494\nsamples = 6\nvalue = [0, 0, 4, 5, 0, 0]'),
#  Text(0.7516930022573364, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.7607223476297968, 0.3, 'X[8] <= 3.34\ngini = 0.32\nsamples = 4\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.7562076749435666, 0.23333333333333334, 'X[11] <= 1433.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.7516930022573364, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7607223476297968, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7652370203160271, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.7607223476297968, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7832957110609481, 0.5666666666666667, 'X[1] <= 0.82\ngini = 0.263\nsamples = 18\nvalue = [0, 2, 0, 23, 2, 0]'),
#  Text(0.7787810383747178, 0.5, 'X[7] <= 0.994\ngini = 0.147\nsamples = 17\nvalue = [0, 0, 0, 23, 2, 0]'),
#  Text(0.7697516930022573, 0.43333333333333335, 'X[8] <= 3.335\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.7652370203160271, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7742663656884876, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7878103837471784, 0.43333333333333335, 'X[10] <= 11.35\ngini = 0.087\nsamples = 14\nvalue = [0, 0, 0, 21, 1, 0]'),
#  Text(0.7832957110609481, 0.36666666666666664, 'X[6] <= 49.0\ngini = 0.245\nsamples = 5\nvalue = [0, 0, 0, 6, 1, 0]'),
#  Text(0.7787810383747178, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7878103837471784, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.7923250564334086, 0.36666666666666664, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 15, 0, 0]'),
#  Text(0.7878103837471784, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.8635722347629797, 0.7666666666666667, 'X[0] <= 7.8\ngini = 0.648\nsamples = 81\nvalue = [0, 1, 12, 53, 47, 9]'),
#  Text(0.809255079006772, 0.7, 'X[8] <= 3.415\ngini = 0.592\nsamples = 36\nvalue = [0, 0, 8, 33, 10, 5]'),
#  Text(0.7968397291196389, 0.6333333333333333, 'X[7] <= 0.995\ngini = 0.095\nsamples = 12\nvalue = [0, 0, 0, 19, 1, 0]'),
#  Text(0.7923250564334086, 0.5666666666666667, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 19, 0, 0]'),
#  Text(0.801354401805869, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8216704288939052, 0.6333333333333333, 'X[6] <= 27.5\ngini = 0.718\nsamples = 24\nvalue = [0, 0, 8, 14, 9, 5]'),
#  Text(0.8103837471783296, 0.5666666666666667, 'X[6] <= 13.5\ngini = 0.32\nsamples = 7\nvalue = [0, 0, 8, 2, 0, 0]'),
#  Text(0.8058690744920993, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8148984198645598, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.8329571106094809, 0.5666666666666667, 'X[2] <= 0.04\ngini = 0.63\nsamples = 17\nvalue = [0, 0, 0, 12, 9, 5]'),
#  Text(0.8239277652370203, 0.5, 'X[8] <= 3.585\ngini = 0.375\nsamples = 9\nvalue = [0, 0, 0, 9, 3, 0]'),
#  Text(0.8194130925507901, 0.43333333333333335, 'X[4] <= 0.078\ngini = 0.48\nsamples = 3\nvalue = [0, 0, 0, 2, 3, 0]'),
#  Text(0.8148984198645598, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.8239277652370203, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8284424379232506, 0.43333333333333335, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.8419864559819413, 0.5, 'X[1] <= 0.705\ngini = 0.643\nsamples = 8\nvalue = [0, 0, 0, 3, 6, 5]'),
#  Text(0.837471783295711, 0.43333333333333335, 'X[7] <= 0.992\ngini = 0.54\nsamples = 7\nvalue = [0, 0, 0, 3, 6, 1]'),
#  Text(0.8329571106094809, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.8419864559819413, 0.36666666666666664, 'X[4] <= 0.06\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 0, 3, 6, 0]'),
#  Text(0.8329571106094809, 0.3, 'X[3] <= 2.3\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.8284424379232506, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.837471783295711, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8510158013544018, 0.3, 'X[11] <= 840.0\ngini = 0.278\nsamples = 4\nvalue = [0, 0, 0, 1, 5, 0]'),
#  Text(0.8465011286681715, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8555304740406321, 0.23333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.8465011286681715, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 4]'),
#  Text(0.9178893905191874, 0.7, 'X[1] <= 0.345\ngini = 0.586\nsamples = 45\nvalue = [0, 1, 4, 20, 37, 4]'),
#  Text(0.8803611738148984, 0.6333333333333333, 'X[5] <= 14.0\ngini = 0.405\nsamples = 22\nvalue = [0, 0, 2, 7, 26, 0]'),
#  Text(0.8690744920993227, 0.5666666666666667, 'X[7] <= 0.996\ngini = 0.234\nsamples = 14\nvalue = [0, 0, 2, 1, 20, 0]'),
#  Text(0.8600451467268623, 0.5, 'X[5] <= 3.5\ngini = 0.1\nsamples = 11\nvalue = [0, 0, 0, 1, 18, 0]'),
#  Text(0.8555304740406321, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8645598194130926, 0.43333333333333335, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 0, 18, 0]'),
#  Text(0.8781038374717833, 0.5, 'X[4] <= 0.065\ngini = 0.5\nsamples = 3\nvalue = [0, 0, 2, 0, 2, 0]'),
#  Text(0.873589164785553, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8826185101580135, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.891647855530474, 0.5666666666666667, 'X[10] <= 12.1\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 0, 6, 6, 0]'),
#  Text(0.8871331828442438, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8961625282167043, 0.5, 'X[7] <= 0.992\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 0, 3, 6, 0]'),
#  Text(0.891647855530474, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9006772009029346, 0.43333333333333335, 'X[8] <= 3.245\ngini = 0.245\nsamples = 5\nvalue = [0, 0, 0, 1, 6, 0]'),
#  Text(0.8961625282167043, 0.36666666666666664, 'X[5] <= 26.25\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.891647855530474, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9006772009029346, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9051918735891648, 0.36666666666666664, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.9554176072234764, 0.6333333333333333, 'X[5] <= 5.5\ngini = 0.676\nsamples = 23\nvalue = [0, 1, 2, 13, 11, 4]'),
#  Text(0.9322799097065463, 0.5666666666666667, 'X[2] <= 0.505\ngini = 0.37\nsamples = 6\nvalue = [0, 1, 0, 7, 1, 0]'),
#  Text(0.9232505643340858, 0.5, 'X[1] <= 0.43\ngini = 0.245\nsamples = 4\nvalue = [0, 1, 0, 6, 0, 0]'),
#  Text(0.9187358916478555, 0.43333333333333335, 'X[9] <= 0.565\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.9142212189616253, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9232505643340858, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.927765237020316, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.9413092550790068, 0.5, 'X[11] <= 1038.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.9367945823927766, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.945823927765237, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9785553047404063, 0.5666666666666667, 'X[8] <= 3.345\ngini = 0.678\nsamples = 17\nvalue = [0, 0, 2, 6, 10, 4]'),
#  Text(0.9661399548532731, 0.5, 'X[11] <= 535.0\ngini = 0.617\nsamples = 13\nvalue = [0, 0, 2, 4, 10, 2]'),
#  Text(0.9548532731376975, 0.43333333333333335, 'X[2] <= 0.665\ngini = 0.459\nsamples = 10\nvalue = [0, 0, 1, 1, 10, 2]'),
#  Text(0.945823927765237, 0.36666666666666664, 'X[10] <= 13.7\ngini = 0.18\nsamples = 7\nvalue = [0, 0, 0, 1, 9, 0]'),
#  Text(0.9413092550790068, 0.3, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 9, 0]'),
#  Text(0.9503386004514672, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.963882618510158, 0.36666666666666664, 'X[3] <= 5.0\ngini = 0.625\nsamples = 3\nvalue = [0, 0, 1, 0, 1, 2]'),
#  Text(0.9593679458239278, 0.3, 'X[4] <= 0.093\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.9548532731376975, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.963882618510158, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9683972911963883, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.9774266365688488, 0.43333333333333335, 'X[0] <= 13.4\ngini = 0.375\nsamples = 3\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.9729119638826185, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.981941309255079, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9909706546275395, 0.5, 'X[1] <= 0.425\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 0, 2, 0, 2]'),
#  Text(0.9864559819413092, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.9954853273137697, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]')]

# %%
plt.figure(figsize=(20,20))
tree.plot_tree(rf.estimators_[0],filled=True)
# Out:
# [Text(0.37744250846501126, 0.9666666666666667, 'X[10] <= 9.75\ngini = 0.653\nsamples = 529\nvalue = [6, 33, 337, 360, 102, 19]'),
#  Text(0.1544864559819413, 0.9, 'X[5] <= 15.5\ngini = 0.46\nsamples = 167\nvalue = [2, 18, 184, 61, 0, 0]'),
#  Text(0.11371331828442438, 0.8333333333333334, 'X[11] <= 998.0\ngini = 0.54\nsamples = 94\nvalue = [2, 11, 88, 47, 0, 0]'),
#  Text(0.07618510158013544, 0.7666666666666667, 'X[3] <= 1.95\ngini = 0.492\nsamples = 85\nvalue = [2, 5, 85, 40, 0, 0]'),
#  Text(0.045146726862302484, 0.7, 'X[2] <= 0.58\ngini = 0.335\nsamples = 37\nvalue = [0, 1, 46, 11, 0, 0]'),
#  Text(0.040632054176072234, 0.6333333333333333, 'X[1] <= 0.553\ngini = 0.318\nsamples = 36\nvalue = [0, 1, 46, 10, 0, 0]'),
#  Text(0.022573363431151242, 0.5666666666666667, 'X[9] <= 0.645\ngini = 0.463\nsamples = 14\nvalue = [0, 0, 14, 8, 0, 0]'),
#  Text(0.013544018058690745, 0.5, 'X[10] <= 9.25\ngini = 0.231\nsamples = 9\nvalue = [0, 0, 13, 2, 0, 0]'),
#  Text(0.009029345372460496, 0.43333333333333335, 'X[1] <= 0.425\ngini = 0.48\nsamples = 4\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.004514672686230248, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.013544018058690745, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.01805869074492099, 0.43333333333333335, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.03160270880361174, 0.5, 'X[2] <= 0.385\ngini = 0.245\nsamples = 5\nvalue = [0, 0, 1, 6, 0, 0]'),
#  Text(0.02708803611738149, 0.43333333333333335, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.03611738148984198, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.05869074492099323, 0.5666666666666667, 'X[4] <= 0.062\ngini = 0.16\nsamples = 22\nvalue = [0, 1, 32, 2, 0, 0]'),
#  Text(0.04966139954853273, 0.5, 'X[0] <= 7.35\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.045146726862302484, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.05417607223476298, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.06772009029345373, 0.5, 'X[0] <= 7.3\ngini = 0.114\nsamples = 20\nvalue = [0, 0, 31, 2, 0, 0]'),
#  Text(0.06320541760722348, 0.43333333333333335, 'X[4] <= 0.08\ngini = 0.231\nsamples = 9\nvalue = [0, 0, 13, 2, 0, 0]'),
#  Text(0.05869074492099323, 0.36666666666666664, 'X[5] <= 7.5\ngini = 0.444\nsamples = 5\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(0.05417607223476298, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.06320541760722348, 0.3, 'X[6] <= 25.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.05869074492099323, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.06772009029345373, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.06772009029345373, 0.36666666666666664, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.07223476297968397, 0.43333333333333335, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 18, 0, 0, 0]'),
#  Text(0.04966139954853273, 0.6333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1072234762979684, 0.7, 'X[3] <= 2.15\ngini = 0.565\nsamples = 48\nvalue = [2, 4, 39, 29, 0, 0]'),
#  Text(0.09029345372460497, 0.6333333333333333, 'X[9] <= 0.525\ngini = 0.579\nsamples = 20\nvalue = [1, 4, 8, 18, 0, 0]'),
#  Text(0.08577878103837472, 0.5666666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.09480812641083522, 0.5666666666666667, 'X[1] <= 0.662\ngini = 0.51\nsamples = 17\nvalue = [1, 4, 4, 18, 0, 0]'),
#  Text(0.08577878103837472, 0.5, 'X[4] <= 0.195\ngini = 0.185\nsamples = 13\nvalue = [1, 0, 1, 18, 0, 0]'),
#  Text(0.08126410835214447, 0.43333333333333335, 'X[8] <= 3.355\ngini = 0.1\nsamples = 12\nvalue = [0, 0, 1, 18, 0, 0]'),
#  Text(0.07674943566591422, 0.36666666666666664, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 15, 0, 0]'),
#  Text(0.08577878103837472, 0.36666666666666664, 'X[7] <= 0.997\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.08126410835214447, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.09029345372460497, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.09029345372460497, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.1038374717832957, 0.5, 'X[6] <= 79.5\ngini = 0.49\nsamples = 4\nvalue = [0, 4, 3, 0, 0, 0]'),
#  Text(0.09932279909706546, 0.43333333333333335, 'X[2] <= 0.02\ngini = 0.32\nsamples = 3\nvalue = [0, 4, 1, 0, 0, 0]'),
#  Text(0.09480812641083522, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.1038374717832957, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 4, 0, 0, 0, 0]'),
#  Text(0.10835214446952596, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.12415349887133183, 0.6333333333333333, 'X[1] <= 0.275\ngini = 0.414\nsamples = 28\nvalue = [1, 0, 31, 11, 0, 0]'),
#  Text(0.11963882618510158, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.12866817155756208, 0.5666666666666667, 'X[7] <= 0.996\ngini = 0.359\nsamples = 26\nvalue = [1, 0, 31, 8, 0, 0]'),
#  Text(0.12415349887133183, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.13318284424379231, 0.5, 'X[1] <= 0.78\ngini = 0.309\nsamples = 25\nvalue = [1, 0, 31, 6, 0, 0]'),
#  Text(0.12189616252821671, 0.43333333333333335, 'X[10] <= 9.25\ngini = 0.251\nsamples = 23\nvalue = [1, 0, 30, 4, 0, 0]'),
#  Text(0.11286681715575621, 0.36666666666666664, 'X[5] <= 12.0\ngini = 0.594\nsamples = 6\nvalue = [1, 0, 4, 3, 0, 0]'),
#  Text(0.10835214446952596, 0.3, 'X[6] <= 45.0\ngini = 0.32\nsamples = 4\nvalue = [1, 0, 4, 0, 0, 0]'),
#  Text(0.1038374717832957, 0.23333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.11286681715575621, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.11738148984198646, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.1309255079006772, 0.36666666666666664, 'X[6] <= 13.5\ngini = 0.071\nsamples = 17\nvalue = [0, 0, 26, 1, 0, 0]'),
#  Text(0.12641083521444696, 0.3, 'X[2] <= 0.56\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.12189616252821671, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1309255079006772, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.13544018058690746, 0.3, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 25, 0, 0, 0]'),
#  Text(0.14446952595936793, 0.43333333333333335, 'X[11] <= 264.5\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.1399548532731377, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.1489841986455982, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.15124153498871332, 0.7666666666666667, 'X[2] <= 0.075\ngini = 0.633\nsamples = 9\nvalue = [0, 6, 3, 7, 0, 0]'),
#  Text(0.14672686230248308, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 6, 0, 0, 0, 0]'),
#  Text(0.15575620767494355, 0.7, 'X[5] <= 11.5\ngini = 0.42\nsamples = 7\nvalue = [0, 0, 3, 7, 0, 0]'),
#  Text(0.15124153498871332, 0.6333333333333333, 'X[2] <= 0.105\ngini = 0.5\nsamples = 5\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(0.14672686230248308, 0.5666666666666667, 'X[6] <= 11.5\ngini = 0.375\nsamples = 3\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.14221218961625282, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.15124153498871332, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.15575620767494355, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.16027088036117382, 0.6333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.19525959367945825, 0.8333333333333334, 'X[3] <= 1.55\ngini = 0.309\nsamples = 73\nvalue = [0, 7, 96, 14, 0, 0]'),
#  Text(0.19074492099322798, 0.7666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.19977426636568849, 0.7666666666666667, 'X[1] <= 0.385\ngini = 0.286\nsamples = 72\nvalue = [0, 5, 96, 14, 0, 0]'),
#  Text(0.17832957110609482, 0.7, 'X[2] <= 0.445\ngini = 0.625\nsamples = 7\nvalue = [0, 2, 5, 5, 0, 0]'),
#  Text(0.16930022573363432, 0.6333333333333333, 'X[3] <= 2.9\ngini = 0.278\nsamples = 4\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(0.16478555304740405, 0.5666666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.17381489841986456, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.1873589164785553, 0.6333333333333333, 'X[11] <= 691.0\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 4, 0, 0, 0]'),
#  Text(0.18284424379232506, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.19187358916478556, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.22121896162528218, 0.7, 'X[6] <= 99.5\ngini = 0.211\nsamples = 65\nvalue = [0, 3, 91, 9, 0, 0]'),
#  Text(0.21670428893905191, 0.6333333333333333, 'X[3] <= 3.95\ngini = 0.322\nsamples = 42\nvalue = [0, 3, 51, 9, 0, 0]'),
#  Text(0.20090293453724606, 0.5666666666666667, 'X[1] <= 0.435\ngini = 0.251\nsamples = 37\nvalue = [0, 3, 49, 5, 0, 0]'),
#  Text(0.19187358916478556, 0.5, 'X[10] <= 9.45\ngini = 0.397\nsamples = 8\nvalue = [0, 0, 8, 3, 0, 0]'),
#  Text(0.1873589164785553, 0.43333333333333335, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.1963882618510158, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.20993227990970656, 0.5, 'X[11] <= 61.5\ngini = 0.199\nsamples = 29\nvalue = [0, 3, 41, 2, 0, 0]'),
#  Text(0.2054176072234763, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.2144469525959368, 0.43333333333333335, 'X[9] <= 0.78\ngini = 0.129\nsamples = 28\nvalue = [0, 1, 41, 2, 0, 0]'),
#  Text(0.20316027088036118, 0.36666666666666664, 'X[6] <= 90.5\ngini = 0.094\nsamples = 26\nvalue = [0, 1, 39, 1, 0, 0]'),
#  Text(0.19413092550790068, 0.3, 'X[10] <= 9.05\ngini = 0.051\nsamples = 24\nvalue = [0, 1, 37, 0, 0, 0]'),
#  Text(0.18961625282167044, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.1986455981941309, 0.23333333333333334, 'gini = 0.0\nsamples = 23\nvalue = [0, 0, 37, 0, 0, 0]'),
#  Text(0.21218961625282168, 0.3, 'X[1] <= 0.51\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.2076749435665914, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.21670428893905191, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.22573363431151242, 0.36666666666666664, 'X[6] <= 50.5\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.22121896162528218, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.23024830699774265, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2325056433408578, 0.5666666666666667, 'X[9] <= 0.65\ngini = 0.444\nsamples = 5\nvalue = [0, 0, 2, 4, 0, 0]'),
#  Text(0.22799097065462753, 0.5, 'X[3] <= 5.3\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.2234762979683973, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2325056433408578, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.23702031602708803, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.22573363431151242, 0.6333333333333333, 'gini = 0.0\nsamples = 23\nvalue = [0, 0, 40, 0, 0, 0]'),
#  Text(0.6003985609480813, 0.9, 'X[10] <= 10.75\ngini = 0.647\nsamples = 362\nvalue = [4, 15, 153, 299, 102, 19]'),
#  Text(0.44723476297968395, 0.8333333333333334, 'X[1] <= 0.605\ngini = 0.585\nsamples = 169\nvalue = [4, 5, 106, 150, 20, 2]'),
#  Text(0.39418735891647855, 0.7666666666666667, 'X[4] <= 0.09\ngini = 0.541\nsamples = 111\nvalue = [0, 2, 54, 120, 18, 2]'),
#  Text(0.3594808126410835, 0.7, 'X[2] <= 0.58\ngini = 0.477\nsamples = 81\nvalue = [0, 0, 32, 94, 10, 2]'),
#  Text(0.3306997742663657, 0.6333333333333333, 'X[11] <= 1390.5\ngini = 0.442\nsamples = 76\nvalue = [0, 0, 26, 93, 10, 1]'),
#  Text(0.3002257336343115, 0.5666666666666667, 'X[0] <= 6.4\ngini = 0.339\nsamples = 63\nvalue = [0, 0, 16, 91, 7, 0]'),
#  Text(0.29571106094808125, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3047404063205418, 0.5, 'X[8] <= 3.425\ngini = 0.32\nsamples = 62\nvalue = [0, 0, 14, 91, 7, 0]'),
#  Text(0.2799097065462754, 0.43333333333333335, 'X[9] <= 0.645\ngini = 0.265\nsamples = 52\nvalue = [0, 0, 7, 80, 7, 0]'),
#  Text(0.25733634311512416, 0.36666666666666664, 'X[8] <= 3.255\ngini = 0.213\nsamples = 36\nvalue = [0, 0, 7, 59, 1, 0]'),
#  Text(0.23927765237020315, 0.3, 'X[6] <= 23.5\ngini = 0.444\nsamples = 12\nvalue = [0, 0, 6, 12, 0, 0]'),
#  Text(0.23476297968397292, 0.23333333333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.24379232505643342, 0.23333333333333334, 'X[1] <= 0.26\ngini = 0.496\nsamples = 7\nvalue = [0, 0, 6, 5, 0, 0]'),
#  Text(0.23927765237020315, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.24830699774266365, 0.16666666666666666, 'X[11] <= 657.5\ngini = 0.469\nsamples = 6\nvalue = [0, 0, 3, 5, 0, 0]'),
#  Text(0.24379232505643342, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.2528216704288939, 0.1, 'X[6] <= 36.5\ngini = 0.375\nsamples = 3\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.24830699774266365, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.25733634311512416, 0.03333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.27539503386004516, 0.3, 'X[4] <= 0.087\ngini = 0.079\nsamples = 24\nvalue = [0, 0, 1, 47, 1, 0]'),
#  Text(0.2708803611738149, 0.23333333333333334, 'X[0] <= 7.15\ngini = 0.041\nsamples = 23\nvalue = [0, 0, 1, 47, 0, 0]'),
#  Text(0.26636568848758463, 0.16666666666666666, 'X[7] <= 0.996\ngini = 0.111\nsamples = 8\nvalue = [0, 0, 1, 16, 0, 0]'),
#  Text(0.2618510158013544, 0.1, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.2708803611738149, 0.1, 'X[1] <= 0.435\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.26636568848758463, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.27539503386004516, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.27539503386004516, 0.16666666666666666, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 0, 31, 0, 0]'),
#  Text(0.2799097065462754, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.30248306997742663, 0.36666666666666664, 'X[7] <= 0.997\ngini = 0.346\nsamples = 16\nvalue = [0, 0, 0, 21, 6, 0]'),
#  Text(0.29345372460496616, 0.3, 'X[7] <= 0.997\ngini = 0.5\nsamples = 5\nvalue = [0, 0, 0, 4, 4, 0]'),
#  Text(0.28893905191873587, 0.23333333333333334, 'X[7] <= 0.996\ngini = 0.32\nsamples = 3\nvalue = [0, 0, 0, 4, 1, 0]'),
#  Text(0.28442437923250563, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.29345372460496616, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.2979683972911964, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.3115124153498871, 0.3, 'X[9] <= 0.775\ngini = 0.188\nsamples = 11\nvalue = [0, 0, 0, 17, 2, 0]'),
#  Text(0.30699774266365687, 0.23333333333333334, 'X[0] <= 9.1\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.30248306997742663, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.3115124153498871, 0.16666666666666666, 'X[3] <= 2.25\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.30699774266365687, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.3160270880361174, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3160270880361174, 0.23333333333333334, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 16, 0, 0]'),
#  Text(0.3295711060948081, 0.43333333333333335, 'X[9] <= 0.625\ngini = 0.475\nsamples = 10\nvalue = [0, 0, 7, 11, 0, 0]'),
#  Text(0.32505643340857787, 0.36666666666666664, 'X[10] <= 10.45\ngini = 0.219\nsamples = 6\nvalue = [0, 0, 7, 1, 0, 0]'),
#  Text(0.32054176072234764, 0.3, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.3295711060948081, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3340857787810384, 0.36666666666666664, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.3611738148984199, 0.5666666666666667, 'X[8] <= 3.315\ngini = 0.555\nsamples = 13\nvalue = [0, 0, 10, 2, 3, 1]'),
#  Text(0.35214446952595935, 0.5, 'X[8] <= 3.28\ngini = 0.719\nsamples = 7\nvalue = [0, 0, 3, 2, 2, 1]'),
#  Text(0.3476297968397291, 0.43333333333333335, 'X[6] <= 16.0\ngini = 0.611\nsamples = 6\nvalue = [0, 0, 3, 2, 0, 1]'),
#  Text(0.3431151241534989, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.35214446952595935, 0.36666666666666664, 'X[0] <= 7.7\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.3476297968397291, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.35665914221218964, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.35665914221218964, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.37020316027088035, 0.5, 'X[9] <= 0.66\ngini = 0.219\nsamples = 6\nvalue = [0, 0, 7, 0, 1, 0]'),
#  Text(0.3656884875846501, 0.43333333333333335, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.3747178329571106, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.38826185101580135, 0.6333333333333333, 'X[2] <= 0.69\ngini = 0.406\nsamples = 5\nvalue = [0, 0, 6, 1, 0, 1]'),
#  Text(0.3837471783295711, 0.5666666666666667, 'X[0] <= 12.55\ngini = 0.245\nsamples = 4\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(0.3792325056433409, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.38826185101580135, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3927765237020316, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.4288939051918736, 0.7, 'X[10] <= 10.35\ngini = 0.635\nsamples = 30\nvalue = [0, 2, 22, 26, 8, 0]'),
#  Text(0.4108352144469526, 0.6333333333333333, 'X[11] <= 569.5\ngini = 0.544\nsamples = 17\nvalue = [0, 2, 4, 21, 6, 0]'),
#  Text(0.4018058690744921, 0.5666666666666667, 'X[9] <= 0.55\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 2, 20, 0, 0]'),
#  Text(0.3972911963882618, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.40632054176072235, 0.5, 'X[11] <= 437.5\ngini = 0.091\nsamples = 10\nvalue = [0, 0, 1, 20, 0, 0]'),
#  Text(0.4018058690744921, 0.43333333333333335, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.4108352144469526, 0.43333333333333335, 'X[5] <= 12.5\ngini = 0.245\nsamples = 3\nvalue = [0, 0, 1, 6, 0, 0]'),
#  Text(0.40632054176072235, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4153498871331828, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.4198645598194131, 0.5666666666666667, 'X[9] <= 0.58\ngini = 0.628\nsamples = 6\nvalue = [0, 2, 2, 1, 6, 0]'),
#  Text(0.4153498871331828, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.42437923250564336, 0.5, 'X[6] <= 55.5\ngini = 0.494\nsamples = 5\nvalue = [0, 0, 2, 1, 6, 0]'),
#  Text(0.4198645598194131, 0.43333333333333335, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.4288939051918736, 0.43333333333333335, 'X[1] <= 0.36\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.42437923250564336, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.43340857787810383, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.4469525959367946, 0.6333333333333333, 'X[9] <= 0.715\ngini = 0.435\nsamples = 13\nvalue = [0, 0, 18, 5, 2, 0]'),
#  Text(0.43792325056433407, 0.5666666666666667, 'X[3] <= 3.2\ngini = 0.1\nsamples = 9\nvalue = [0, 0, 18, 1, 0, 0]'),
#  Text(0.43340857787810383, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 18, 0, 0, 0]'),
#  Text(0.44243792325056436, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.45598194130925507, 0.5666666666666667, 'X[11] <= 388.0\ngini = 0.444\nsamples = 4\nvalue = [0, 0, 0, 4, 2, 0]'),
#  Text(0.45146726862302483, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.4604966139954853, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.5002821670428894, 0.7666666666666667, 'X[4] <= 0.065\ngini = 0.561\nsamples = 58\nvalue = [4, 3, 52, 30, 2, 0]'),
#  Text(0.4762979683972912, 0.7, 'X[2] <= 0.035\ngini = 0.494\nsamples = 6\nvalue = [0, 2, 0, 6, 1, 0]'),
#  Text(0.4717832957110609, 0.6333333333333333, 'X[7] <= 0.996\ngini = 0.444\nsamples = 2\nvalue = [0, 2, 0, 0, 1, 0]'),
#  Text(0.4672686230248307, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.4762979683972912, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.48081264108352145, 0.6333333333333333, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.5242663656884876, 0.7, 'X[2] <= 0.31\ngini = 0.51\nsamples = 52\nvalue = [4, 1, 52, 24, 1, 0]'),
#  Text(0.5067720090293454, 0.6333333333333333, 'X[0] <= 7.55\ngini = 0.474\nsamples = 49\nvalue = [4, 1, 52, 20, 0, 0]'),
#  Text(0.4853273137697517, 0.5666666666666667, 'X[11] <= 1391.5\ngini = 0.32\nsamples = 25\nvalue = [4, 1, 31, 2, 0, 0]'),
#  Text(0.46952595936794583, 0.5, 'X[7] <= 0.995\ngini = 0.142\nsamples = 18\nvalue = [0, 0, 24, 2, 0, 0]'),
#  Text(0.4604966139954853, 0.43333333333333335, 'X[5] <= 14.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.45598194130925507, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4650112866817156, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4785553047404063, 0.43333333333333335, 'X[9] <= 0.845\ngini = 0.08\nsamples = 16\nvalue = [0, 0, 23, 1, 0, 0]'),
#  Text(0.47404063205417607, 0.36666666666666664, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 23, 0, 0, 0]'),
#  Text(0.48306997742663654, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5011286681715575, 0.5, 'X[5] <= 9.0\ngini = 0.542\nsamples = 7\nvalue = [4, 1, 7, 0, 0, 0]'),
#  Text(0.4966139954853273, 0.43333333333333335, 'X[8] <= 3.605\ngini = 0.32\nsamples = 3\nvalue = [4, 1, 0, 0, 0, 0]'),
#  Text(0.49209932279909707, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [4, 0, 0, 0, 0, 0]'),
#  Text(0.5011286681715575, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5056433408577878, 0.43333333333333335, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.5282167042889391, 0.5666666666666667, 'X[10] <= 10.3\ngini = 0.497\nsamples = 24\nvalue = [0, 0, 21, 18, 0, 0]'),
#  Text(0.5237020316027088, 0.5, 'X[6] <= 18.0\ngini = 0.346\nsamples = 18\nvalue = [0, 0, 21, 6, 0, 0]'),
#  Text(0.5146726862302483, 0.43333333333333335, 'X[7] <= 0.997\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.510158013544018, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5191873589164786, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5327313769751693, 0.43333333333333335, 'X[11] <= 258.0\ngini = 0.278\nsamples = 16\nvalue = [0, 0, 20, 4, 0, 0]'),
#  Text(0.5282167042889391, 0.36666666666666664, 'X[0] <= 8.15\ngini = 0.32\nsamples = 4\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.5237020316027088, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.5327313769751693, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5372460496613995, 0.36666666666666664, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 19, 0, 0, 0]'),
#  Text(0.5327313769751693, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.5417607223476298, 0.6333333333333333, 'X[11] <= 397.5\ngini = 0.32\nsamples = 3\nvalue = [0, 0, 0, 4, 1, 0]'),
#  Text(0.5372460496613995, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.54627539503386, 0.5666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.7535623589164786, 0.8333333333333334, 'X[10] <= 11.65\ngini = 0.661\nsamples = 193\nvalue = [0, 10, 47, 149, 82, 17]'),
#  Text(0.6435524830699775, 0.7666666666666667, 'X[5] <= 5.5\ngini = 0.647\nsamples = 112\nvalue = [0, 9, 35, 96, 35, 8]'),
#  Text(0.5733634311512416, 0.7, 'X[1] <= 0.36\ngini = 0.774\nsamples = 20\nvalue = [0, 5, 10, 12, 7, 5]'),
#  Text(0.5598194130925508, 0.6333333333333333, 'X[4] <= 0.067\ngini = 0.631\nsamples = 6\nvalue = [0, 0, 0, 3, 7, 5]'),
#  Text(0.5553047404063205, 0.5666666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.5643340857787811, 0.5666666666666667, 'X[0] <= 9.9\ngini = 0.469\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 5]'),
#  Text(0.5598194130925508, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.5688487584650113, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 5]'),
#  Text(0.5869074492099323, 0.6333333333333333, 'X[7] <= 0.998\ngini = 0.642\nsamples = 14\nvalue = [0, 5, 10, 9, 0, 0]'),
#  Text(0.582392776523702, 0.5666666666666667, 'X[6] <= 13.5\ngini = 0.602\nsamples = 10\nvalue = [0, 5, 3, 9, 0, 0]'),
#  Text(0.5778781038374717, 0.5, 'X[1] <= 0.465\ngini = 0.469\nsamples = 5\nvalue = [0, 5, 3, 0, 0, 0]'),
#  Text(0.5733634311512416, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.582392776523702, 0.43333333333333335, 'X[3] <= 2.3\ngini = 0.48\nsamples = 4\nvalue = [0, 2, 3, 0, 0, 0]'),
#  Text(0.5778781038374717, 0.36666666666666664, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.5869074492099323, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.5869074492099323, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.5914221218961625, 0.5666666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.7137415349887133, 0.7, 'X[6] <= 34.5\ngini = 0.591\nsamples = 92\nvalue = [0, 4, 25, 84, 28, 3]'),
#  Text(0.6645033860045146, 0.6333333333333333, 'X[11] <= 981.5\ngini = 0.632\nsamples = 49\nvalue = [0, 2, 9, 39, 25, 3]'),
#  Text(0.6331828442437923, 0.5666666666666667, 'X[7] <= 0.998\ngini = 0.59\nsamples = 18\nvalue = [0, 0, 5, 8, 16, 0]'),
#  Text(0.6162528216704289, 0.5, 'X[7] <= 0.996\ngini = 0.475\nsamples = 14\nvalue = [0, 0, 5, 2, 15, 0]'),
#  Text(0.6049661399548533, 0.43333333333333335, 'X[7] <= 0.994\ngini = 0.625\nsamples = 6\nvalue = [0, 0, 4, 2, 2, 0]'),
#  Text(0.5959367945823928, 0.36666666666666664, 'X[9] <= 0.63\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.5914221218961625, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.600451467268623, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6139954853273137, 0.36666666666666664, 'X[2] <= 0.09\ngini = 0.32\nsamples = 4\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.6094808126410836, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.618510158013544, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.6275395033860045, 0.43333333333333335, 'X[11] <= 475.5\ngini = 0.133\nsamples = 8\nvalue = [0, 0, 1, 0, 13, 0]'),
#  Text(0.6230248306997742, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6320541760722348, 0.36666666666666664, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 13, 0]'),
#  Text(0.6501128668171557, 0.5, 'X[11] <= 401.5\ngini = 0.245\nsamples = 4\nvalue = [0, 0, 0, 6, 1, 0]'),
#  Text(0.6455981941309256, 0.43333333333333335, 'X[2] <= 0.61\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.6410835214446953, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.6501128668171557, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.654627539503386, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.695823927765237, 0.5666666666666667, 'X[5] <= 16.5\ngini = 0.554\nsamples = 31\nvalue = [0, 2, 4, 31, 9, 3]'),
#  Text(0.6805869074492099, 0.5, 'X[9] <= 0.665\ngini = 0.491\nsamples = 29\nvalue = [0, 2, 4, 31, 7, 1]'),
#  Text(0.6636568848758465, 0.43333333333333335, 'X[11] <= 1290.0\ngini = 0.227\nsamples = 13\nvalue = [0, 0, 3, 20, 0, 0]'),
#  Text(0.6591422121896162, 0.36666666666666664, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 16, 0, 0]'),
#  Text(0.6681715575620768, 0.36666666666666664, 'X[5] <= 12.0\ngini = 0.49\nsamples = 5\nvalue = [0, 0, 3, 4, 0, 0]'),
#  Text(0.6636568848758465, 0.3, 'X[5] <= 7.0\ngini = 0.375\nsamples = 3\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.6591422121896162, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6681715575620768, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.672686230248307, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.6975169300225733, 0.43333333333333335, 'X[11] <= 1134.5\ngini = 0.636\nsamples = 16\nvalue = [0, 2, 1, 11, 7, 1]'),
#  Text(0.6930022573363431, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.7020316027088036, 0.36666666666666664, 'X[7] <= 0.996\ngini = 0.62\nsamples = 14\nvalue = [0, 2, 1, 11, 5, 1]'),
#  Text(0.6862302483069977, 0.3, 'X[2] <= 0.315\ngini = 0.612\nsamples = 6\nvalue = [0, 0, 1, 1, 4, 1]'),
#  Text(0.6772009029345373, 0.23333333333333334, 'X[8] <= 3.325\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.672686230248307, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.6817155756207675, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6952595936794582, 0.23333333333333334, 'X[5] <= 9.5\ngini = 0.32\nsamples = 4\nvalue = [0, 0, 1, 0, 4, 0]'),
#  Text(0.690744920993228, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6997742663656885, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.7178329571106095, 0.3, 'X[8] <= 3.415\ngini = 0.379\nsamples = 8\nvalue = [0, 2, 0, 10, 1, 0]'),
#  Text(0.7133182844243793, 0.23333333333333334, 'X[0] <= 7.85\ngini = 0.165\nsamples = 7\nvalue = [0, 0, 0, 10, 1, 0]'),
#  Text(0.708803611738149, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7178329571106095, 0.16666666666666666, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.7223476297968398, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.7110609480812641, 0.5, 'X[4] <= 0.068\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 2]'),
#  Text(0.7065462753950339, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.7155756207674944, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.7629796839729119, 0.6333333333333333, 'X[10] <= 11.15\ngini = 0.473\nsamples = 43\nvalue = [0, 2, 16, 45, 3, 0]'),
#  Text(0.7426636568848759, 0.5666666666666667, 'X[6] <= 50.5\ngini = 0.513\nsamples = 25\nvalue = [0, 0, 16, 22, 1, 0]'),
#  Text(0.7291196388261851, 0.5, 'X[9] <= 0.585\ngini = 0.431\nsamples = 14\nvalue = [0, 0, 5, 15, 1, 0]'),
#  Text(0.7246049661399548, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.7336343115124153, 0.43333333333333335, 'X[8] <= 3.395\ngini = 0.215\nsamples = 12\nvalue = [0, 0, 1, 15, 1, 0]'),
#  Text(0.7291196388261851, 0.36666666666666664, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 13, 0, 0]'),
#  Text(0.7381489841986456, 0.36666666666666664, 'X[6] <= 36.0\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 2, 1, 0]'),
#  Text(0.7336343115124153, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7426636568848759, 0.3, 'X[1] <= 0.48\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.7381489841986456, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7471783295711061, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7562076749435666, 0.5, 'X[4] <= 0.103\ngini = 0.475\nsamples = 11\nvalue = [0, 0, 11, 7, 0, 0]'),
#  Text(0.7516930022573364, 0.43333333333333335, 'X[11] <= 1105.0\ngini = 0.43\nsamples = 9\nvalue = [0, 0, 11, 5, 0, 0]'),
#  Text(0.7471783295711061, 0.36666666666666664, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.7562076749435666, 0.36666666666666664, 'X[1] <= 0.51\ngini = 0.494\nsamples = 6\nvalue = [0, 0, 4, 5, 0, 0]'),
#  Text(0.7516930022573364, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.7607223476297968, 0.3, 'X[8] <= 3.34\ngini = 0.32\nsamples = 4\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.7562076749435666, 0.23333333333333334, 'X[11] <= 1433.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.7516930022573364, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7607223476297968, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7652370203160271, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.7607223476297968, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7832957110609481, 0.5666666666666667, 'X[1] <= 0.82\ngini = 0.263\nsamples = 18\nvalue = [0, 2, 0, 23, 2, 0]'),
#  Text(0.7787810383747178, 0.5, 'X[7] <= 0.994\ngini = 0.147\nsamples = 17\nvalue = [0, 0, 0, 23, 2, 0]'),
#  Text(0.7697516930022573, 0.43333333333333335, 'X[8] <= 3.335\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.7652370203160271, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7742663656884876, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7878103837471784, 0.43333333333333335, 'X[10] <= 11.35\ngini = 0.087\nsamples = 14\nvalue = [0, 0, 0, 21, 1, 0]'),
#  Text(0.7832957110609481, 0.36666666666666664, 'X[6] <= 49.0\ngini = 0.245\nsamples = 5\nvalue = [0, 0, 0, 6, 1, 0]'),
#  Text(0.7787810383747178, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7878103837471784, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.7923250564334086, 0.36666666666666664, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 15, 0, 0]'),
#  Text(0.7878103837471784, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.8635722347629797, 0.7666666666666667, 'X[0] <= 7.8\ngini = 0.648\nsamples = 81\nvalue = [0, 1, 12, 53, 47, 9]'),
#  Text(0.809255079006772, 0.7, 'X[8] <= 3.415\ngini = 0.592\nsamples = 36\nvalue = [0, 0, 8, 33, 10, 5]'),
#  Text(0.7968397291196389, 0.6333333333333333, 'X[7] <= 0.995\ngini = 0.095\nsamples = 12\nvalue = [0, 0, 0, 19, 1, 0]'),
#  Text(0.7923250564334086, 0.5666666666666667, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 19, 0, 0]'),
#  Text(0.801354401805869, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8216704288939052, 0.6333333333333333, 'X[6] <= 27.5\ngini = 0.718\nsamples = 24\nvalue = [0, 0, 8, 14, 9, 5]'),
#  Text(0.8103837471783296, 0.5666666666666667, 'X[6] <= 13.5\ngini = 0.32\nsamples = 7\nvalue = [0, 0, 8, 2, 0, 0]'),
#  Text(0.8058690744920993, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8148984198645598, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.8329571106094809, 0.5666666666666667, 'X[2] <= 0.04\ngini = 0.63\nsamples = 17\nvalue = [0, 0, 0, 12, 9, 5]'),
#  Text(0.8239277652370203, 0.5, 'X[8] <= 3.585\ngini = 0.375\nsamples = 9\nvalue = [0, 0, 0, 9, 3, 0]'),
#  Text(0.8194130925507901, 0.43333333333333335, 'X[4] <= 0.078\ngini = 0.48\nsamples = 3\nvalue = [0, 0, 0, 2, 3, 0]'),
#  Text(0.8148984198645598, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.8239277652370203, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8284424379232506, 0.43333333333333335, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.8419864559819413, 0.5, 'X[1] <= 0.705\ngini = 0.643\nsamples = 8\nvalue = [0, 0, 0, 3, 6, 5]'),
#  Text(0.837471783295711, 0.43333333333333335, 'X[7] <= 0.992\ngini = 0.54\nsamples = 7\nvalue = [0, 0, 0, 3, 6, 1]'),
#  Text(0.8329571106094809, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.8419864559819413, 0.36666666666666664, 'X[4] <= 0.06\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 0, 3, 6, 0]'),
#  Text(0.8329571106094809, 0.3, 'X[3] <= 2.3\ngini = 0.444\nsamples = 2\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.8284424379232506, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.837471783295711, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8510158013544018, 0.3, 'X[11] <= 840.0\ngini = 0.278\nsamples = 4\nvalue = [0, 0, 0, 1, 5, 0]'),
#  Text(0.8465011286681715, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8555304740406321, 0.23333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.8465011286681715, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 4]'),
#  Text(0.9178893905191874, 0.7, 'X[1] <= 0.345\ngini = 0.586\nsamples = 45\nvalue = [0, 1, 4, 20, 37, 4]'),
#  Text(0.8803611738148984, 0.6333333333333333, 'X[5] <= 14.0\ngini = 0.405\nsamples = 22\nvalue = [0, 0, 2, 7, 26, 0]'),
#  Text(0.8690744920993227, 0.5666666666666667, 'X[7] <= 0.996\ngini = 0.234\nsamples = 14\nvalue = [0, 0, 2, 1, 20, 0]'),
#  Text(0.8600451467268623, 0.5, 'X[5] <= 3.5\ngini = 0.1\nsamples = 11\nvalue = [0, 0, 0, 1, 18, 0]'),
#  Text(0.8555304740406321, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8645598194130926, 0.43333333333333335, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 0, 18, 0]'),
#  Text(0.8781038374717833, 0.5, 'X[4] <= 0.065\ngini = 0.5\nsamples = 3\nvalue = [0, 0, 2, 0, 2, 0]'),
#  Text(0.873589164785553, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8826185101580135, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.891647855530474, 0.5666666666666667, 'X[10] <= 12.1\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 0, 6, 6, 0]'),
#  Text(0.8871331828442438, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8961625282167043, 0.5, 'X[7] <= 0.992\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 0, 3, 6, 0]'),
#  Text(0.891647855530474, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9006772009029346, 0.43333333333333335, 'X[8] <= 3.245\ngini = 0.245\nsamples = 5\nvalue = [0, 0, 0, 1, 6, 0]'),
#  Text(0.8961625282167043, 0.36666666666666664, 'X[5] <= 26.25\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.891647855530474, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9006772009029346, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9051918735891648, 0.36666666666666664, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.9554176072234764, 0.6333333333333333, 'X[5] <= 5.5\ngini = 0.676\nsamples = 23\nvalue = [0, 1, 2, 13, 11, 4]'),
#  Text(0.9322799097065463, 0.5666666666666667, 'X[2] <= 0.505\ngini = 0.37\nsamples = 6\nvalue = [0, 1, 0, 7, 1, 0]'),
#  Text(0.9232505643340858, 0.5, 'X[1] <= 0.43\ngini = 0.245\nsamples = 4\nvalue = [0, 1, 0, 6, 0, 0]'),
#  Text(0.9187358916478555, 0.43333333333333335, 'X[9] <= 0.565\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.9142212189616253, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9232505643340858, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.927765237020316, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.9413092550790068, 0.5, 'X[11] <= 1038.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.9367945823927766, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.945823927765237, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9785553047404063, 0.5666666666666667, 'X[8] <= 3.345\ngini = 0.678\nsamples = 17\nvalue = [0, 0, 2, 6, 10, 4]'),
#  Text(0.9661399548532731, 0.5, 'X[11] <= 535.0\ngini = 0.617\nsamples = 13\nvalue = [0, 0, 2, 4, 10, 2]'),
#  Text(0.9548532731376975, 0.43333333333333335, 'X[2] <= 0.665\ngini = 0.459\nsamples = 10\nvalue = [0, 0, 1, 1, 10, 2]'),
#  Text(0.945823927765237, 0.36666666666666664, 'X[10] <= 13.7\ngini = 0.18\nsamples = 7\nvalue = [0, 0, 0, 1, 9, 0]'),
#  Text(0.9413092550790068, 0.3, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 9, 0]'),
#  Text(0.9503386004514672, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.963882618510158, 0.36666666666666664, 'X[3] <= 5.0\ngini = 0.625\nsamples = 3\nvalue = [0, 0, 1, 0, 1, 2]'),
#  Text(0.9593679458239278, 0.3, 'X[4] <= 0.093\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.9548532731376975, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.963882618510158, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9683972911963883, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.9774266365688488, 0.43333333333333335, 'X[0] <= 13.4\ngini = 0.375\nsamples = 3\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.9729119638826185, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.981941309255079, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9909706546275395, 0.5, 'X[1] <= 0.425\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 0, 2, 0, 2]'),
#  Text(0.9864559819413092, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.9954853273137697, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]')]

# %%
plt.figure(figsize=(20,20))
for i in range(len(rf.estimators_)):
    tree.plot_tree(rf.estimators_[i], filled=True)
